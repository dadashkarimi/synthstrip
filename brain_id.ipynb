# %% [markdown]
# # Brain Identification

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from neurite.tf import models  # Assuming the module's location
import voxelmorph.tf.losses as vtml
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from keras.callbacks import ReduceLROnPlateau

from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Lambda
import neurite as ne
import sys
import nibabel as nib

import os
import tensorflow as tf

import numpy as np
from keras.callbacks import LearningRateScheduler

def step_decay(epoch):
    initial_lr = 0.0001
    drop = 0.5
    epochs_drop = 10.0
    lr = initial_lr * (drop ** (epoch // epochs_drop))
    return lr
    
tf.get_logger().setLevel('ERROR')

import os
import random
num_gen = 20
nb_labels=2
nb_features=64
batch_size=4
warp_max=2   
warp_max=2.5
warp_min=.5
warp_blur_min=np.array([2, 4, 8])
warp_blur_max=warp_blur_min*2
bias_blur_min=np.array([2, 4, 8])
bias_blur_max=bias_blur_min*2
initial_lr=1e-4
lr = 1e-4
lr_lin = 1e-4
nb_levels=5
conv_size=3

num_epochs=40000
initial_epoch = 8000
models_dir="models.bi.zb.0.2"
zero_background=0.2

# checkpoint_callback = PeriodicModelSaver(filepath=models_dir)
checkpoint_path = models_dir+'/weights_epoch_2000.h5'

import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    tf.config.experimental.set_visible_devices(gpus[0], 'GPU')

log_dir = "logs.bi.zb.0.2"  # Specify the directory where you want to save logs
summary_writer = tf.summary.create_file_writer(log_dir)


from tensorflow.keras.callbacks import ModelCheckpoint

class CustomTensorBoard(tf.keras.callbacks.TensorBoard):
    def __init__(self, base_log_dir, **kwargs):
        super(CustomTensorBoard, self).__init__(**kwargs)
        self.base_log_dir = base_log_dir

    def on_epoch_begin(self, epoch, logs=None):
        if epoch % 200 == 0:  # Check if it's the start of a new set of 50 epochs
            self.log_dir = f"{self.base_log_dir}/epoch_{epoch}"
            super().set_model(self.model)




class PeriodicWeightsSaver(tf.keras.callbacks.Callback):
    def __init__(self, filepath, save_freq=200, **kwargs):
        super().__init__(**kwargs)
        self.filepath = filepath
        self.save_freq = save_freq

    def on_epoch_end(self, epoch, logs=None):
        # Save the weights every `save_freq` epochs
        if (epoch + 1) % self.save_freq == 0:
            weights_path = os.path.join(self.filepath, f"weights_epoch_{epoch + 1}.h5")
            self.model.save_weights(weights_path)
            print(f"Saved weights to {weights_path}")


weights_saver = PeriodicWeightsSaver(filepath=models_dir, save_freq=50)  # Save weights every 5 epochs

TB_callback = CustomTensorBoard(
    base_log_dir=log_dir,
    histogram_freq=0,
    write_graph=True,
    write_images=False,
    write_steps_per_second=False,
    update_freq='epoch',
    profile_batch=0,
    embeddings_freq=0,
    embeddings_metadata=None
)


class PeriodicModelSaver(tf.keras.callbacks.Callback):
    def __init__(self, filepath, save_freq=200, **kwargs):
        super().__init__(**kwargs)
        self.filepath = filepath
        self.save_freq = save_freq

    def on_epoch_end(self, epoch, logs=None):
        # Save the model every `save_freq` epochs
        if (epoch + 1) % self.save_freq == 0:
            save_path = os.path.join(self.filepath, f"model_epoch_{epoch + 1}.h5")
            self.model.save(save_path)
            print(f"Saved model to {save_path}")




def dice_loss(y_true, y_pred):
    ndims = len(y_pred.get_shape().as_list()) - 2
    vol_axes = list(range(1, ndims + 1))

    top = 2 * tf.reduce_sum(y_true * y_pred, vol_axes)
    bottom = tf.reduce_sum(y_true + y_pred, vol_axes)

    div_no_nan = tf.math.divide_no_nan if hasattr(
        tf.math, 'divide_no_nan') else tf.div_no_nan  # pylint: disable=no-member
    dice = tf.reduce_mean(div_no_nan(top, bottom))
    return -dice
    
def dice_coefficient(y_true, y_pred):
    ndims = len(y_pred.get_shape().as_list()) - 2
    vol_axes = list(range(1, ndims + 1))

    top = 2 * tf.reduce_sum(y_true * y_pred, vol_axes)
    bottom = tf.reduce_sum(y_true + y_pred, vol_axes)

    div_no_nan = tf.math.divide_no_nan if hasattr(
    tf.math, 'divide_no_nan') else tf.div_no_nan  # pylint: disable=no-member
    dice = tf.reduce_mean(div_no_nan(top, bottom))
    return dice

def one_hot_encode_image(img, depth=2):
    img = tf.convert_to_tensor(img)
    
    one_hot_img = tf.one_hot(tf.cast(img[..., 0], tf.int32), depth=depth)
    
    return one_hot_img
    
slice_seg24_list = []
slice_norm_list = []

for i in range(401):
    file_path = "neurite-oasis.2d.v1.0/OASIS_OAS1_"+str(i).zfill(4)+"_MR1/slice_seg24.nii.gz"
    file_path_norm = "neurite-oasis.2d.v1.0/OASIS_OAS1_"+str(i).zfill(4)+"_MR1/slice_norm.nii.gz"
    if os.path.exists(file_path):
        img = nib.load(file_path)
        img = img.get_fdata()

        norm = nib.load(file_path_norm)
        norm = norm.get_fdata()

        num_segments = len(np.unique(img).astype(int))
        slice_seg24_list.append(img)
        slice_norm_list.append(norm)
    else:
        continue

slice_seg24_array = np.array(slice_seg24_list)
slice_norm_array = np.array(slice_norm_list)

train_indices, test_indices = train_test_split(range(len(slice_seg24_array)), test_size=0.2, random_state=42)
slice_seg24_array_train = [slice_seg24_array[i] for i in train_indices]
slice_seg24_array_test = [slice_seg24_array[i] for i in test_indices]

slice_norm_array_train = [slice_norm_array[i] for i in train_indices]
slice_norm_array_test = [slice_norm_array[i] for i in test_indices]


def my_generator(label_maps, batch_size=1, same_subj=False, flip=False):
    print(len(label_maps))
    in_shape = label_maps[0].shape
    num_dim = len(in_shape)
    void = np.zeros((batch_size, *in_shape), dtype='float32')
    rand = np.random.default_rng()
    prop = dict(replace=False, shuffle=False)
    num_batches = len(label_maps) // batch_size
    while True:
        ind = rand.integers(len(label_maps), size=2 * batch_size)
        x = [label_maps[i] for i in ind]
        if same_subj:
            x = x[:batch_size] * 2
        x = np.stack(x)[..., None]

        if flip:
            axes = rand.choice(num_dim, size=rand.integers(num_dim + 1), **prop)
            x = np.flip(x, axis=axes + 1)

        src = x[:batch_size, ...,0]
        y = np.array(void)
        yield src, y
        

in_shape = (160,192)
input_image = slice_seg24_array_train


gen_arg = {
    'in_shape': in_shape,
    'labels_in': [i for i in range(25)],
    'labels_out': {i: 1 if i > 0 else 0 for i in range(25)},  # This line creates the desired mapping
    'warp_min': 0.01,
    'warp_max': 2.5,
    'zero_background': zero_background
}




unet_model = models.unet(input_shape=(160, 192, 1), nb_features=nb_features, nb_labels=nb_labels, nb_levels=nb_levels, conv_size=conv_size)

slices= []
maps=[]




gen_model_1 = ne.models.labels_to_image_new(**gen_arg, id=1)
input_img = Input(shape=(160, 192,1))


generated_img, y = gen_model_1(input_img)
print(generated_img.shape,y.shape)
segmentation = unet_model(generated_img)

combined_model = Model(inputs=input_img, outputs=segmentation)
combined_model.add_loss(dice_loss(y, segmentation))
combined_model.compile(optimizer=Adam(learning_rate=initial_lr))

print(len(slice_seg24_array_test))
gen  = my_generator(input_image,batch_size=batch_size, same_subj=False, flip=False)

steps_per_epoch = len(slice_seg24_array_train) // 1  
validation_steps = len(slice_seg24_array_test) // 1  

from tensorflow.keras.models import load_model

if os.path.exists(checkpoint_path):
    combined_model.load_weights(checkpoint_path)
    print("Loaded weights from the checkpoint and continued training.")
else:
    print("Checkpoint file not found.")

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',  # Monitor validation loss for learning rate reduction
    factor=0.2,  # Reduce learning rate by a factor of 0.2 when triggered
    patience=5,  # Number of epochs with no improvement before reducing learning rate
    min_lr=1e-6,  # Minimum learning rate
    verbose=0  # Display messages about learning rate reduction
)



hist = combined_model.fit(
    gen,
    epochs=num_epochs,  # Set the total number of epochs including previous ones
    initial_epoch=initial_epoch,  # Specify the initial epoch
    verbose=0,
    steps_per_epoch=10,
    callbacks=[weights_saver, TB_callback]
)
# Out:
# using final_pred_activation softmax for unet
# (None, 160, 192, 1) (None, 160, 192, 2)
# 73
# Checkpoint file not found.
# 288
# Saved weights to models.bi.zb.0.2/weights_epoch_8050.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_8100.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_8150.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_8200.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_8250.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_8300.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_8350.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_8400.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_8450.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_8500.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_8550.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_8600.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_8650.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_8700.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_8750.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_8800.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_8850.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_8900.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_8950.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_9000.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_9050.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_9100.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_9150.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_9200.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_9250.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_9300.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_9350.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_9400.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_9450.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_9500.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_9550.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_9600.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_9650.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_9700.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_9750.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_9800.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_9850.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_9900.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_9950.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_10000.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_10050.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_10100.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_10150.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_10200.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_10250.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_10300.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_10350.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_10400.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_10450.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_10500.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_10550.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_10600.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_10650.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_10700.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_10750.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_10800.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_10850.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_10900.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_10950.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_11000.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_11050.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_11100.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_11150.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_11200.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_11250.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_11300.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_11350.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_11400.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_11450.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_11500.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_11550.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_11600.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_11650.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_11700.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_11750.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_11800.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_11850.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_11900.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_11950.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_12000.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_12050.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_12100.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_12150.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_12200.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_12250.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_12300.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_12350.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_12400.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_12450.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_12500.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_12550.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_12600.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_12650.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_12700.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_12750.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_12800.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_12850.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_12900.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_12950.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_13000.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_13050.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_13100.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_13150.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_13200.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_13250.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_13300.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_13350.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_13400.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_13450.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_13500.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_13550.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_13600.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_13650.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_13700.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_13750.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_13800.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_13850.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_13900.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_13950.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_14000.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_14050.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_14100.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_14150.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_14200.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_14250.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_14300.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_14350.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_14400.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_14450.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_14500.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_14550.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_14600.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_14650.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_14700.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_14750.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_14800.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_14850.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_14900.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_14950.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_15000.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_15050.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_15100.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_15150.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_15200.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_15250.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_15300.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_15350.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_15400.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_15450.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_15500.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_15550.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_15600.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_15650.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_15700.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_15750.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_15800.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_15850.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_15900.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_15950.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_16000.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_16050.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_16100.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_16150.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_16200.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_16250.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_16300.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_16350.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_16400.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_16450.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_16500.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_16550.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_16600.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_16650.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_16700.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_16750.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_16800.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_16850.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_16900.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_16950.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_17000.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_17050.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_17100.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_17150.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_17200.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_17250.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_17300.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_17350.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_17400.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_17450.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_17500.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_17550.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_17600.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_17650.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_17700.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_17750.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_17800.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_17850.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_17900.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_17950.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_18000.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_18050.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_18100.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_18150.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_18200.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_18250.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_18300.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_18350.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_18400.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_18450.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_18500.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_18550.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_18600.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_18650.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_18700.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_18750.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_18800.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_18850.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_18900.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_18950.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_19000.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_19050.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_19100.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_19150.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_19200.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_19250.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_19300.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_19350.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_19400.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_19450.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_19500.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_19550.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_19600.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_19650.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_19700.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_19750.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_19800.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_19850.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_19900.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_19950.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_20000.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_20050.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_20100.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_20150.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_20200.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_20250.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_20300.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_20350.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_20400.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_20450.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_20500.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_20550.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_20600.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_20650.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_20700.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_20750.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_20800.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_20850.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_20900.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_20950.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_21000.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_21050.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_21100.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_21150.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_21200.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_21250.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_21300.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_21350.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_21400.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_21450.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_21500.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_21550.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_21600.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_21650.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_21700.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_21750.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_21800.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_21850.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_21900.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_21950.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_22000.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_22050.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_22100.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_22150.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_22200.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_22250.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_22300.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_22350.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_22400.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_22450.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_22500.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_22550.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_22600.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_22650.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_22700.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_22750.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_22800.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_22850.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_22900.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_22950.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_23000.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_23050.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_23100.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_23150.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_23200.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_23250.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_23300.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_23350.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_23400.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_23450.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_23500.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_23550.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_23600.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_23650.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_23700.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_23750.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_23800.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_23850.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_23900.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_23950.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_24000.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_24050.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_24100.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_24150.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_24200.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_24250.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_24300.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_24350.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_24400.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_24450.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_24500.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_24550.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_24600.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_24650.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_24700.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_24750.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_24800.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_24850.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_24900.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_24950.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_25000.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_25050.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_25100.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_25150.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_25200.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_25250.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_25300.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_25350.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_25400.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_25450.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_25500.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_25550.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_25600.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_25650.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_25700.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_25750.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_25800.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_25850.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_25900.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_25950.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_26000.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_26050.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_26100.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_26150.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_26200.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_26250.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_26300.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_26350.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_26400.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_26450.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_26500.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_26550.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_26600.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_26650.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_26700.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_26750.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_26800.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_26850.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_26900.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_26950.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_27000.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_27050.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_27100.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_27150.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_27200.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_27250.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_27300.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_27350.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_27400.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_27450.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_27500.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_27550.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_27600.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_27650.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_27700.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_27750.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_27800.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_27850.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_27900.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_27950.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_28000.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_28050.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_28100.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_28150.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_28200.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_28250.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_28300.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_28350.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_28400.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_28450.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_28500.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_28550.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_28600.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_28650.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_28700.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_28750.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_28800.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_28850.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_28900.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_28950.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_29000.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_29050.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_29100.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_29150.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_29200.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_29250.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_29300.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_29350.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_29400.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_29450.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_29500.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_29550.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_29600.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_29650.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_29700.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_29750.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_29800.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_29850.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_29900.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_29950.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_30000.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_30050.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_30100.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_30150.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_30200.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_30250.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_30300.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_30350.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_30400.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_30450.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_30500.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_30550.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_30600.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_30650.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_30700.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_30750.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_30800.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_30850.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_30900.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_30950.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_31000.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_31050.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_31100.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_31150.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_31200.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_31250.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_31300.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_31350.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_31400.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_31450.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_31500.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_31550.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_31600.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_31650.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_31700.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_31750.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_31800.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_31850.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_31900.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_31950.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_32000.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_32050.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_32100.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_32150.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_32200.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_32250.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_32300.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_32350.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_32400.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_32450.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_32500.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_32550.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_32600.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_32650.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_32700.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_32750.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_32800.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_32850.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_32900.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_32950.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_33000.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_33050.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_33100.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_33150.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_33200.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_33250.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_33300.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_33350.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_33400.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_33450.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_33500.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_33550.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_33600.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_33650.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_33700.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_33750.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_33800.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_33850.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_33900.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_33950.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_34000.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_34050.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_34100.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_34150.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_34200.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_34250.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_34300.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_34350.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_34400.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_34450.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_34500.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_34550.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_34600.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_34650.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_34700.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_34750.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_34800.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_34850.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_34900.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_34950.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_35000.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_35050.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_35100.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_35150.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_35200.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_35250.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_35300.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_35350.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_35400.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_35450.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_35500.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_35550.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_35600.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_35650.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_35700.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_35750.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_35800.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_35850.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_35900.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_35950.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_36000.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_36050.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_36100.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_36150.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_36200.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_36250.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_36300.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_36350.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_36400.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_36450.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_36500.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_36550.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_36600.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_36650.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_36700.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_36750.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_36800.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_36850.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_36900.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_36950.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_37000.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_37050.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_37100.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_37150.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_37200.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_37250.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_37300.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_37350.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_37400.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_37450.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_37500.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_37550.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_37600.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_37650.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_37700.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_37750.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_37800.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_37850.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_37900.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_37950.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_38000.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_38050.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_38100.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_38150.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_38200.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_38250.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_38300.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_38350.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_38400.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_38450.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_38500.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_38550.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_38600.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_38650.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_38700.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_38750.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_38800.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_38850.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_38900.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_38950.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_39000.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_39050.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_39100.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_39150.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_39200.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_39250.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_39300.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_39350.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_39400.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_39450.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_39500.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_39550.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_39600.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_39650.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_39700.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_39750.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_39800.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_39850.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_39900.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_39950.h5
# Saved weights to models.bi.zb.0.2/weights_epoch_40000.h5
