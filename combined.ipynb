# %% [markdown]
# # Combined Model

# %%
# !ps aux | grep -i jupy
# !which python
import neurite as ne
print(ne.__file__)
import tensorflow as tf
import voxelmorph as vxm
# !pip install -e ../voxelmorph
gpus = tf.config.experimental.list_physical_devices(device_type='GPU')
cpus = tf.config.experimental.list_physical_devices(device_type='CPU')
print(gpus, cpus)

if tf.config.experimental.list_physical_devices('GPU'):
    print("Using GPU")
else:
    print("Using CPU")
# Out:
# jd1677     80268  0.4  0.0 744904 127656 ?       Sl   Oct17  13:45 /usr/bin/python3 /autofs/cluster/scratch/friday/javid/tensorflow_2.13.0-gpu-user-base/bin/jupyter-lab --ip=0.0.0.0 --port=8888 --no-browse --num_gpus=1 --batch_size=32 --model=vgg19 --data_format=NHWC
# jd1677     80699  0.0  0.0 700484 62312 ?        Ssl  Oct17   0:08 /usr/bin/python3 -m ipykernel_launcher -f /homes/3/jd1677/.local/share/jupyter/runtime/kernel-dd245b5e-b4a8-478f-9a7a-4276705e9d12.json
# jd1677     80706  0.0  0.0 700096 59568 ?        Ssl  Oct17   0:08 /usr/bin/python3 -m ipykernel_launcher -f /homes/3/jd1677/.local/share/jupyter/runtime/kernel-09910f56-18bc-4d4e-9d16-0d6eb8c9a7df.json
# jd1677     80707  3.9  3.9 53050416 31041052 ?   Ssl  Oct17 113:08 /usr/bin/python3 -m ipykernel_launcher -f /homes/3/jd1677/.local/share/jupyter/runtime/kernel-238c2007-1d0c-4064-a38e-408916d3d9a1.json
# jd1677     80709  0.0  0.0 700100 59608 ?        Ssl  Oct17   0:08 /usr/bin/python3 -m ipykernel_launcher -f /homes/3/jd1677/.local/share/jupyter/runtime/kernel-9897eed5-8046-4cf5-b35c-711becd381c9.json
# jd1677     93947  0.1  0.2 22907464 1952504 ?    Ssl  Oct17   4:53 /usr/bin/python3 -m ipykernel_launcher -f /homes/3/jd1677/.local/share/jupyter/runtime/kernel-d3e45bf5-11ee-4bb6-ae15-7fcb87ee7ffd.json
# jd1677    122576  0.0  0.0 700100 61532 ?        Ssl  Oct17   0:08 /usr/bin/python3 -m ipykernel_launcher -f /homes/3/jd1677/.local/share/jupyter/runtime/kernel-bb94ee40-f3d1-4bf0-8246-431526816b35.json
# jd1677    736155  171  0.5 55144884 4301312 ?    Ssl  Oct18 2439:37 /usr/bin/python3 -m ipykernel_launcher -f /homes/3/jd1677/.local/share/jupyter/runtime/kernel-35855dbe-5947-4bd0-b8c8-3787b1a615d0.json
# jd1677   2064189 18.0  0.0   5796  3320 pts/1    Ss+  09:59   0:00 /bin/bash -c ps aux | grep -i jupy
# jd1677   2064192  0.0  0.0   5204  2372 pts/1    S+   09:59   0:00 grep -i jupy
# Illegal option --
# Usage: /usr/bin/which [-a] args
# /autofs/space/bal_004/users/jd1677/neurite/neurite/__init__.py
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:2', device_type='GPU')] [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
# Using GPU

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from neurite.tf import models  # Assuming the module's location
import voxelmorph.tf.losses as vtml
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from keras.callbacks import ReduceLROnPlateau

from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Lambda
import neurite as ne
import sys
import nibabel as nib

import numpy as np
from keras.callbacks import LearningRateScheduler

def step_decay(epoch):
    initial_lr = 0.0001
    drop = 0.5
    epochs_drop = 10.0
    lr = initial_lr * (drop ** (epoch // epochs_drop))
    return lr
    
tf.get_logger().setLevel('ERROR')

import os


import random
num_gen = 20

nb_features=64
batch_size=8
warp_max=2   
warp_max=2.5
warp_min=.5
warp_blur_min=np.array([2, 4, 8])
warp_blur_max=warp_blur_min*2
bias_blur_min=np.array([2, 4, 8])
bias_blur_max=bias_blur_min*2
initial_lr=1e-4
lr = 1e-4
lr_lin = 1e-4
nb_levels=5
conv_size=3

num_epochs=1000000
initial_epoch = 78800
checkpoint_path = 'models2/weights_epoch_78800.h5'

import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    tf.config.experimental.set_visible_devices(gpus[0], 'GPU')

log_dir = "logs2"  # Specify the directory where you want to save logs
summary_writer = tf.summary.create_file_writer(log_dir)


# def dice_coefficient(y_true, y_pred):
#     dice = ne.tf.metrics.Dice()  # you can pass any arguments if you want different configurations
#     return dice.mean_dice(y_true, y_pred)

from tensorflow.keras.callbacks import ModelCheckpoint

class CustomTensorBoard(tf.keras.callbacks.TensorBoard):
    def __init__(self, base_log_dir, **kwargs):
        super(CustomTensorBoard, self).__init__(**kwargs)
        self.base_log_dir = base_log_dir

    def on_epoch_begin(self, epoch, logs=None):
        if epoch % 200 == 0:  # Check if it's the start of a new set of 50 epochs
            self.log_dir = f"{self.base_log_dir}/epoch_{epoch}"
            super().set_model(self.model)



import os
import tensorflow as tf

class PeriodicWeightsSaver(tf.keras.callbacks.Callback):
    def __init__(self, filepath, save_freq=200, **kwargs):
        super().__init__(**kwargs)
        self.filepath = filepath
        self.save_freq = save_freq

    def on_epoch_end(self, epoch, logs=None):
        # Save the weights every `save_freq` epochs
        if (epoch + 1) % self.save_freq == 0:
            weights_path = os.path.join(self.filepath, f"weights_epoch_{epoch + 1}.h5")
            self.model.save_weights(weights_path)
            print(f"Saved weights to {weights_path}")


weights_saver = PeriodicWeightsSaver(filepath="models2", save_freq=50)  # Save weights every 5 epochs

TB_callback = CustomTensorBoard(
    base_log_dir=log_dir,
    histogram_freq=0,
    write_graph=True,
    write_images=False,
    write_steps_per_second=False,
    update_freq='epoch',
    profile_batch=0,
    embeddings_freq=0,
    embeddings_metadata=None
)


class PeriodicModelSaver(tf.keras.callbacks.Callback):
    def __init__(self, filepath, save_freq=200, **kwargs):
        super().__init__(**kwargs)
        self.filepath = filepath
        self.save_freq = save_freq

    def on_epoch_end(self, epoch, logs=None):
        # Save the model every `save_freq` epochs
        if (epoch + 1) % self.save_freq == 0:
            save_path = os.path.join(self.filepath, f"model_epoch_{epoch + 1}.h5")
            self.model.save(save_path)
            print(f"Saved model to {save_path}")

checkpoint_callback = PeriodicModelSaver(filepath="models2")


def dice_loss(y_true, y_pred):
    ndims = len(y_pred.get_shape().as_list()) - 2
    vol_axes = list(range(1, ndims + 1))

    top = 2 * tf.reduce_sum(y_true * y_pred, vol_axes)
    bottom = tf.reduce_sum(y_true + y_pred, vol_axes)

    div_no_nan = tf.math.divide_no_nan if hasattr(
        tf.math, 'divide_no_nan') else tf.div_no_nan  # pylint: disable=no-member
    dice = tf.reduce_mean(div_no_nan(top, bottom))
    return -dice
    
def dice_coefficient(y_true, y_pred):
    ndims = len(y_pred.get_shape().as_list()) - 2
    vol_axes = list(range(1, ndims + 1))

    top = 2 * tf.reduce_sum(y_true * y_pred, vol_axes)
    bottom = tf.reduce_sum(y_true + y_pred, vol_axes)

    div_no_nan = tf.math.divide_no_nan if hasattr(
    tf.math, 'divide_no_nan') else tf.div_no_nan  # pylint: disable=no-member
    dice = tf.reduce_mean(div_no_nan(top, bottom))
    return dice

def one_hot_encode_image(img, depth=25):
    img = tf.convert_to_tensor(img)
    
    one_hot_img = tf.one_hot(tf.cast(img[..., 0], tf.int32), depth=depth)
    
    return one_hot_img

# unique_random_numbers = random.sample(range(1, 401), num_gen)

# Load files only if they exist
slice_seg24_list = []
slice_norm_list = []

for i in range(401):
    file_path = "neurite-oasis.2d.v1.0/OASIS_OAS1_"+str(i).zfill(4)+"_MR1/slice_seg24.nii.gz"
    file_path_norm = "neurite-oasis.2d.v1.0/OASIS_OAS1_"+str(i).zfill(4)+"_MR1/slice_norm.nii.gz"
    if os.path.exists(file_path):
        img = nib.load(file_path)
        img = img.get_fdata()

        norm = nib.load(file_path_norm)
        norm = norm.get_fdata()

        num_segments = len(np.unique(img).astype(int))
        slice_seg24_list.append(img)
        slice_norm_list.append(norm)
    else:
        continue

slice_seg24_array = np.array(slice_seg24_list)
slice_norm_array = np.array(slice_norm_list)

train_indices, test_indices = train_test_split(range(len(slice_seg24_array)), test_size=0.2, random_state=42)
slice_seg24_array_train = [slice_seg24_array[i] for i in train_indices]
slice_seg24_array_test = [slice_seg24_array[i] for i in test_indices]

slice_norm_array_train = [slice_norm_array[i] for i in train_indices]
slice_norm_array_test = [slice_norm_array[i] for i in test_indices]


def my_generator(label_maps, batch_size=1, same_subj=False, flip=False):
    print(len(label_maps))
    in_shape = label_maps[0].shape
    num_dim = len(in_shape)
    void = np.zeros((batch_size, *in_shape), dtype='float32')
    rand = np.random.default_rng()
    prop = dict(replace=False, shuffle=False)
    num_batches = len(label_maps) // batch_size
    while True:
        ind = rand.integers(len(label_maps), size=2 * batch_size)
        x = [label_maps[i] for i in ind]
        if same_subj:
            x = x[:batch_size] * 2
        x = np.stack(x)[..., None]

        if flip:
            axes = rand.choice(num_dim, size=rand.integers(num_dim + 1), **prop)
            x = np.flip(x, axis=axes + 1)

        src = x[:batch_size, ...,0]
        y = np.array(void)
        yield src, y
        

in_shape = (160,192)
input_image = slice_seg24_array_train




# print(f'using warp max = {warp_max} and nlabels {nlabels_small}')
# inshape=np_segs[0].shape
gen_arg = dict(
    in_shape=in_shape,
    warp_min=warp_min,
    warp_max=warp_max,
    labels_in=[i for i in range(25)],
    blur_max=2,  # was .5, then 1
    bias_max=.25,  # was 2 then .5
    bias_blur_min=bias_blur_min,
    bias_blur_max=bias_blur_max,
    gamma=0,
    zero_background=.2,
    noise_max=.2,   
    noise_min=.1
)

# gen_arg = dict(
#         in_shape=in_shape,
#         labels_in=[i for i in range(25)],#np.unique(input_image[0]).astype(int),#np.unique(input_image),
#         warp_min=0.01,
#         warp_max=2,
#         zero_background=0.2
#     )

unet_model = models.unet(input_shape=(160, 192, 1), nb_features=nb_features, nb_labels=25, nb_levels=nb_levels, conv_size=conv_size)

slices= []
maps=[]



# with tf.device('/CPU:0'):
gen_model_1 = ne.models.labels_to_image_new(**gen_arg, id=1)
print(gen_model_1.input.shape)
input_img = Input(shape=(160, 192,1))


generated_img, y = gen_model_1(input_img)
print(generated_img.shape,y.shape)
segmentation = unet_model(generated_img)

combined_model = Model(inputs=input_img, outputs=segmentation)
combined_model.add_loss(dice_loss(y, segmentation))
combined_model.compile(optimizer=Adam(learning_rate=initial_lr))

print(len(slice_seg24_array_test))
gen  = my_generator(input_image,batch_size=batch_size, same_subj=False, flip=False)

steps_per_epoch = len(slice_seg24_array_train) // 1  
validation_steps = len(slice_seg24_array_test) // 1  

from tensorflow.keras.models import load_model

if os.path.exists(checkpoint_path):
    combined_model.load_weights(checkpoint_path)
    print("Loaded weights from the checkpoint and continued training.")
else:
    print("Checkpoint file not found.")

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',  # Monitor validation loss for learning rate reduction
    factor=0.2,  # Reduce learning rate by a factor of 0.2 when triggered
    patience=5,  # Number of epochs with no improvement before reducing learning rate
    min_lr=1e-6,  # Minimum learning rate
    verbose=0  # Display messages about learning rate reduction
)



hist = combined_model.fit(
    gen,
    epochs=num_epochs,  # Set the total number of epochs including previous ones
    initial_epoch=initial_epoch,  # Specify the initial epoch
    verbose=0,
    steps_per_epoch=10,
    callbacks=[weights_saver, TB_callback]
)
# Out:
# using final_pred_activation softmax for unet
# (None, 160, 192, 1)
# (None, 160, 192, 1) (None, 160, 192, 25)
# 73
# Loaded weights from the checkpoint and continued training.
# 288
# Saved weights to models2/weights_epoch_78850.h5
# Saved weights to models2/weights_epoch_78900.h5
# Saved weights to models2/weights_epoch_78950.h5
# Saved weights to models2/weights_epoch_79000.h5
# Saved weights to models2/weights_epoch_79050.h5
# Saved weights to models2/weights_epoch_79100.h5
# Saved weights to models2/weights_epoch_79150.h5
# Saved weights to models2/weights_epoch_79200.h5
# Saved weights to models2/weights_epoch_79250.h5
# Saved weights to models2/weights_epoch_79300.h5
# Saved weights to models2/weights_epoch_79350.h5
# Saved weights to models2/weights_epoch_79400.h5
# Saved weights to models2/weights_epoch_79450.h5
# Saved weights to models2/weights_epoch_79500.h5
# Saved weights to models2/weights_epoch_79550.h5
# Saved weights to models2/weights_epoch_79600.h5
# Saved weights to models2/weights_epoch_79650.h5
# Saved weights to models2/weights_epoch_79700.h5
# Saved weights to models2/weights_epoch_79750.h5
# Saved weights to models2/weights_epoch_79800.h5
# Saved weights to models2/weights_epoch_79850.h5
# Saved weights to models2/weights_epoch_79900.h5
# Saved weights to models2/weights_epoch_79950.h5
# Saved weights to models2/weights_epoch_80000.h5
# Saved weights to models2/weights_epoch_80050.h5
# Saved weights to models2/weights_epoch_80100.h5
# Saved weights to models2/weights_epoch_80150.h5
# Saved weights to models2/weights_epoch_80200.h5
# Saved weights to models2/weights_epoch_80250.h5
# Saved weights to models2/weights_epoch_80300.h5
# Saved weights to models2/weights_epoch_80350.h5
# Saved weights to models2/weights_epoch_80400.h5
# Saved weights to models2/weights_epoch_80450.h5
# Saved weights to models2/weights_epoch_80500.h5
# Saved weights to models2/weights_epoch_80550.h5
# Saved weights to models2/weights_epoch_80600.h5
# Saved weights to models2/weights_epoch_80650.h5
# Saved weights to models2/weights_epoch_80700.h5
# Saved weights to models2/weights_epoch_80750.h5
# Saved weights to models2/weights_epoch_80800.h5
# Saved weights to models2/weights_epoch_80850.h5
# Saved weights to models2/weights_epoch_80900.h5
# Saved weights to models2/weights_epoch_80950.h5
# Saved weights to models2/weights_epoch_81000.h5
# Saved weights to models2/weights_epoch_81050.h5
# Saved weights to models2/weights_epoch_81100.h5
# Saved weights to models2/weights_epoch_81150.h5
# Saved weights to models2/weights_epoch_81200.h5
# Saved weights to models2/weights_epoch_81250.h5
# Saved weights to models2/weights_epoch_81300.h5
# Saved weights to models2/weights_epoch_81350.h5
# Saved weights to models2/weights_epoch_81400.h5
# Saved weights to models2/weights_epoch_81450.h5
# Saved weights to models2/weights_epoch_81500.h5
# Saved weights to models2/weights_epoch_81550.h5
# Saved weights to models2/weights_epoch_81600.h5
# Saved weights to models2/weights_epoch_81650.h5
# Saved weights to models2/weights_epoch_81700.h5
# Saved weights to models2/weights_epoch_81750.h5
# Saved weights to models2/weights_epoch_81800.h5
# Saved weights to models2/weights_epoch_81850.h5
# Saved weights to models2/weights_epoch_81900.h5
# Saved weights to models2/weights_epoch_81950.h5
# Saved weights to models2/weights_epoch_82000.h5
# Saved weights to models2/weights_epoch_82050.h5
# Saved weights to models2/weights_epoch_82100.h5
# Saved weights to models2/weights_epoch_82150.h5
# Saved weights to models2/weights_epoch_82200.h5
# Saved weights to models2/weights_epoch_82250.h5
# Saved weights to models2/weights_epoch_82300.h5
# Saved weights to models2/weights_epoch_82350.h5
# Saved weights to models2/weights_epoch_82400.h5
# Saved weights to models2/weights_epoch_82450.h5
# Saved weights to models2/weights_epoch_82500.h5
# Saved weights to models2/weights_epoch_82550.h5
# Saved weights to models2/weights_epoch_82600.h5
# Saved weights to models2/weights_epoch_82650.h5
# Saved weights to models2/weights_epoch_82700.h5
# Saved weights to models2/weights_epoch_82750.h5
# Saved weights to models2/weights_epoch_82800.h5
# Saved weights to models2/weights_epoch_82850.h5
# Saved weights to models2/weights_epoch_82900.h5
# Saved weights to models2/weights_epoch_82950.h5
# Saved weights to models2/weights_epoch_83000.h5
# Saved weights to models2/weights_epoch_83050.h5
# Saved weights to models2/weights_epoch_83100.h5
# Saved weights to models2/weights_epoch_83150.h5
# Saved weights to models2/weights_epoch_83200.h5
# Saved weights to models2/weights_epoch_83250.h5
# Saved weights to models2/weights_epoch_83300.h5
# Saved weights to models2/weights_epoch_83350.h5
# Saved weights to models2/weights_epoch_83400.h5
# Saved weights to models2/weights_epoch_83450.h5
# Saved weights to models2/weights_epoch_83500.h5
# Saved weights to models2/weights_epoch_83550.h5
# Saved weights to models2/weights_epoch_83600.h5
# Saved weights to models2/weights_epoch_83650.h5
# Saved weights to models2/weights_epoch_83700.h5
# Saved weights to models2/weights_epoch_83750.h5
# Saved weights to models2/weights_epoch_83800.h5
# Saved weights to models2/weights_epoch_83850.h5
# Saved weights to models2/weights_epoch_83900.h5
# Saved weights to models2/weights_epoch_83950.h5
# Saved weights to models2/weights_epoch_84000.h5
# Saved weights to models2/weights_epoch_84050.h5
# Saved weights to models2/weights_epoch_84100.h5
# Saved weights to models2/weights_epoch_84150.h5
# Saved weights to models2/weights_epoch_84200.h5
# Saved weights to models2/weights_epoch_84250.h5
# Saved weights to models2/weights_epoch_84300.h5
# Saved weights to models2/weights_epoch_84350.h5
# Saved weights to models2/weights_epoch_84400.h5
# Saved weights to models2/weights_epoch_84450.h5
# Saved weights to models2/weights_epoch_84500.h5
# Saved weights to models2/weights_epoch_84550.h5
# Saved weights to models2/weights_epoch_84600.h5
# Saved weights to models2/weights_epoch_84650.h5
# Saved weights to models2/weights_epoch_84700.h5
# Saved weights to models2/weights_epoch_84750.h5
# Saved weights to models2/weights_epoch_84800.h5
# Saved weights to models2/weights_epoch_84850.h5
# Saved weights to models2/weights_epoch_84900.h5
# Saved weights to models2/weights_epoch_84950.h5
# Saved weights to models2/weights_epoch_85000.h5
# Saved weights to models2/weights_epoch_85050.h5
# Saved weights to models2/weights_epoch_85100.h5
# Saved weights to models2/weights_epoch_85150.h5
# Saved weights to models2/weights_epoch_85200.h5
# Saved weights to models2/weights_epoch_85250.h5
# Saved weights to models2/weights_epoch_85300.h5
# Saved weights to models2/weights_epoch_85350.h5
# Saved weights to models2/weights_epoch_85400.h5
# Saved weights to models2/weights_epoch_85450.h5
# Saved weights to models2/weights_epoch_85500.h5
# Saved weights to models2/weights_epoch_85550.h5
# Saved weights to models2/weights_epoch_85600.h5
# Saved weights to models2/weights_epoch_85650.h5
# Saved weights to models2/weights_epoch_85700.h5
# Saved weights to models2/weights_epoch_85750.h5
# Saved weights to models2/weights_epoch_85800.h5
# Saved weights to models2/weights_epoch_85850.h5
# Saved weights to models2/weights_epoch_85900.h5
# Saved weights to models2/weights_epoch_85950.h5
# Saved weights to models2/weights_epoch_86000.h5
# Saved weights to models2/weights_epoch_86050.h5
# Saved weights to models2/weights_epoch_86100.h5
# Saved weights to models2/weights_epoch_86150.h5
# Saved weights to models2/weights_epoch_86200.h5
# Saved weights to models2/weights_epoch_86250.h5
# Saved weights to models2/weights_epoch_86300.h5
# Saved weights to models2/weights_epoch_86350.h5
# Saved weights to models2/weights_epoch_86400.h5
# Saved weights to models2/weights_epoch_86450.h5
# Saved weights to models2/weights_epoch_86500.h5
# Saved weights to models2/weights_epoch_86550.h5
# Saved weights to models2/weights_epoch_86600.h5
# Saved weights to models2/weights_epoch_86650.h5
# Saved weights to models2/weights_epoch_86700.h5
# Saved weights to models2/weights_epoch_86750.h5
# Saved weights to models2/weights_epoch_86800.h5
# Saved weights to models2/weights_epoch_86850.h5
# Saved weights to models2/weights_epoch_86900.h5
# Saved weights to models2/weights_epoch_86950.h5
# Saved weights to models2/weights_epoch_87000.h5
# Saved weights to models2/weights_epoch_87050.h5
# Saved weights to models2/weights_epoch_87100.h5
# Saved weights to models2/weights_epoch_87150.h5
# Saved weights to models2/weights_epoch_87200.h5
# Saved weights to models2/weights_epoch_87250.h5
# Saved weights to models2/weights_epoch_87300.h5
# Saved weights to models2/weights_epoch_87350.h5
# Saved weights to models2/weights_epoch_87400.h5
# Saved weights to models2/weights_epoch_87450.h5
# Saved weights to models2/weights_epoch_87500.h5
# Saved weights to models2/weights_epoch_87550.h5
# Saved weights to models2/weights_epoch_87600.h5
# Saved weights to models2/weights_epoch_87650.h5
# Saved weights to models2/weights_epoch_87700.h5
# Saved weights to models2/weights_epoch_87750.h5
# Saved weights to models2/weights_epoch_87800.h5
# Saved weights to models2/weights_epoch_87850.h5
# Saved weights to models2/weights_epoch_87900.h5
# Saved weights to models2/weights_epoch_87950.h5
# Saved weights to models2/weights_epoch_88000.h5
# Saved weights to models2/weights_epoch_88050.h5
# Saved weights to models2/weights_epoch_88100.h5
# Saved weights to models2/weights_epoch_88150.h5
# Saved weights to models2/weights_epoch_88200.h5
# Saved weights to models2/weights_epoch_88250.h5
# Saved weights to models2/weights_epoch_88300.h5
# Saved weights to models2/weights_epoch_88350.h5
# Saved weights to models2/weights_epoch_88400.h5
# Saved weights to models2/weights_epoch_88450.h5
# Saved weights to models2/weights_epoch_88500.h5
# Saved weights to models2/weights_epoch_88550.h5
# Saved weights to models2/weights_epoch_88600.h5
# Saved weights to models2/weights_epoch_88650.h5
# Saved weights to models2/weights_epoch_88700.h5
# Saved weights to models2/weights_epoch_88750.h5
# Saved weights to models2/weights_epoch_88800.h5
# Saved weights to models2/weights_epoch_88850.h5
# Saved weights to models2/weights_epoch_88900.h5
# Saved weights to models2/weights_epoch_88950.h5
# Saved weights to models2/weights_epoch_89000.h5
# Saved weights to models2/weights_epoch_89050.h5
# Saved weights to models2/weights_epoch_89100.h5
# Saved weights to models2/weights_epoch_89150.h5
# Saved weights to models2/weights_epoch_89200.h5
# Saved weights to models2/weights_epoch_89250.h5
# Saved weights to models2/weights_epoch_89300.h5
# Saved weights to models2/weights_epoch_89350.h5
# Saved weights to models2/weights_epoch_89400.h5
# Saved weights to models2/weights_epoch_89450.h5
# Saved weights to models2/weights_epoch_89500.h5
# Saved weights to models2/weights_epoch_89550.h5
# Saved weights to models2/weights_epoch_89600.h5
# Saved weights to models2/weights_epoch_89650.h5
# Saved weights to models2/weights_epoch_89700.h5
# Saved weights to models2/weights_epoch_89750.h5
# Saved weights to models2/weights_epoch_89800.h5
# Saved weights to models2/weights_epoch_89850.h5
# Saved weights to models2/weights_epoch_89900.h5
# Saved weights to models2/weights_epoch_89950.h5
# Saved weights to models2/weights_epoch_90000.h5
# Saved weights to models2/weights_epoch_90050.h5
# Saved weights to models2/weights_epoch_90100.h5
# Saved weights to models2/weights_epoch_90150.h5
# Saved weights to models2/weights_epoch_90200.h5
# Saved weights to models2/weights_epoch_90250.h5
# Saved weights to models2/weights_epoch_90300.h5
# Saved weights to models2/weights_epoch_90350.h5
# Saved weights to models2/weights_epoch_90400.h5
# Saved weights to models2/weights_epoch_90450.h5
# Saved weights to models2/weights_epoch_90500.h5
# Saved weights to models2/weights_epoch_90550.h5
# Saved weights to models2/weights_epoch_90600.h5
# Saved weights to models2/weights_epoch_90650.h5
# Saved weights to models2/weights_epoch_90700.h5
# Saved weights to models2/weights_epoch_90750.h5
# Saved weights to models2/weights_epoch_90800.h5
# Saved weights to models2/weights_epoch_90850.h5
# Saved weights to models2/weights_epoch_90900.h5
# Saved weights to models2/weights_epoch_90950.h5
# Saved weights to models2/weights_epoch_91000.h5
# Saved weights to models2/weights_epoch_91050.h5
# Saved weights to models2/weights_epoch_91100.h5
# Saved weights to models2/weights_epoch_91150.h5
# Saved weights to models2/weights_epoch_91200.h5
# Saved weights to models2/weights_epoch_91250.h5
# Saved weights to models2/weights_epoch_91300.h5
# Saved weights to models2/weights_epoch_91350.h5
# Saved weights to models2/weights_epoch_91400.h5
# Saved weights to models2/weights_epoch_91450.h5
# Saved weights to models2/weights_epoch_91500.h5
# Saved weights to models2/weights_epoch_91550.h5
# Saved weights to models2/weights_epoch_91600.h5
# Saved weights to models2/weights_epoch_91650.h5
# Saved weights to models2/weights_epoch_91700.h5
# Saved weights to models2/weights_epoch_91750.h5
# Saved weights to models2/weights_epoch_91800.h5
# Saved weights to models2/weights_epoch_91850.h5
# Saved weights to models2/weights_epoch_91900.h5
# Saved weights to models2/weights_epoch_91950.h5
# Saved weights to models2/weights_epoch_92000.h5
# Saved weights to models2/weights_epoch_92050.h5
# Saved weights to models2/weights_epoch_92100.h5
# Saved weights to models2/weights_epoch_92150.h5
# Saved weights to models2/weights_epoch_92200.h5
# Saved weights to models2/weights_epoch_92250.h5
# Saved weights to models2/weights_epoch_92300.h5
# Saved weights to models2/weights_epoch_92350.h5
# Saved weights to models2/weights_epoch_92400.h5
# Saved weights to models2/weights_epoch_92450.h5
# Saved weights to models2/weights_epoch_92500.h5
# Saved weights to models2/weights_epoch_92550.h5
# Saved weights to models2/weights_epoch_92600.h5
# Saved weights to models2/weights_epoch_92650.h5
# Saved weights to models2/weights_epoch_92700.h5
# Saved weights to models2/weights_epoch_92750.h5
# Saved weights to models2/weights_epoch_92800.h5
# Saved weights to models2/weights_epoch_92850.h5
# Saved weights to models2/weights_epoch_92900.h5
# Saved weights to models2/weights_epoch_92950.h5
# Saved weights to models2/weights_epoch_93000.h5
# Saved weights to models2/weights_epoch_93050.h5
# Saved weights to models2/weights_epoch_93100.h5
# Saved weights to models2/weights_epoch_93150.h5
# Saved weights to models2/weights_epoch_93200.h5
# Saved weights to models2/weights_epoch_93250.h5
# Saved weights to models2/weights_epoch_93300.h5
# Saved weights to models2/weights_epoch_93350.h5
# Saved weights to models2/weights_epoch_93400.h5
# Saved weights to models2/weights_epoch_93450.h5
# Saved weights to models2/weights_epoch_93500.h5
# Saved weights to models2/weights_epoch_93550.h5
# Saved weights to models2/weights_epoch_93600.h5
# Saved weights to models2/weights_epoch_93650.h5
# Saved weights to models2/weights_epoch_93700.h5
# Saved weights to models2/weights_epoch_93750.h5
# Saved weights to models2/weights_epoch_93800.h5
# Saved weights to models2/weights_epoch_93850.h5
# Saved weights to models2/weights_epoch_93900.h5
# Saved weights to models2/weights_epoch_93950.h5
# Saved weights to models2/weights_epoch_94000.h5
# Saved weights to models2/weights_epoch_94050.h5
# Saved weights to models2/weights_epoch_94100.h5
# Saved weights to models2/weights_epoch_94150.h5
# Saved weights to models2/weights_epoch_94200.h5
# Saved weights to models2/weights_epoch_94250.h5
# Saved weights to models2/weights_epoch_94300.h5
# Saved weights to models2/weights_epoch_94350.h5
# Saved weights to models2/weights_epoch_94400.h5
# Saved weights to models2/weights_epoch_94450.h5
# Saved weights to models2/weights_epoch_94500.h5
# Saved weights to models2/weights_epoch_94550.h5
# Saved weights to models2/weights_epoch_94600.h5
# Saved weights to models2/weights_epoch_94650.h5
# Saved weights to models2/weights_epoch_94700.h5
# Saved weights to models2/weights_epoch_94750.h5
# Saved weights to models2/weights_epoch_94800.h5
# Saved weights to models2/weights_epoch_94850.h5
# Saved weights to models2/weights_epoch_94900.h5
# Saved weights to models2/weights_epoch_94950.h5
# Saved weights to models2/weights_epoch_95000.h5
# Saved weights to models2/weights_epoch_95050.h5
# Saved weights to models2/weights_epoch_95100.h5
# Saved weights to models2/weights_epoch_95150.h5
# Saved weights to models2/weights_epoch_95200.h5
# Saved weights to models2/weights_epoch_95250.h5
# Saved weights to models2/weights_epoch_95300.h5
# Saved weights to models2/weights_epoch_95350.h5
# Saved weights to models2/weights_epoch_95400.h5
# Saved weights to models2/weights_epoch_95450.h5
# Saved weights to models2/weights_epoch_95500.h5
# Saved weights to models2/weights_epoch_95550.h5
# Saved weights to models2/weights_epoch_95600.h5
# Saved weights to models2/weights_epoch_95650.h5
# Saved weights to models2/weights_epoch_95700.h5
# Saved weights to models2/weights_epoch_95750.h5
# Saved weights to models2/weights_epoch_95800.h5
# Saved weights to models2/weights_epoch_95850.h5
# Saved weights to models2/weights_epoch_95900.h5
# Saved weights to models2/weights_epoch_95950.h5
# Saved weights to models2/weights_epoch_96000.h5
# Saved weights to models2/weights_epoch_96050.h5
# Saved weights to models2/weights_epoch_96100.h5
# Saved weights to models2/weights_epoch_96150.h5
# Saved weights to models2/weights_epoch_96200.h5
# Saved weights to models2/weights_epoch_96250.h5
# Saved weights to models2/weights_epoch_96300.h5
# Saved weights to models2/weights_epoch_96350.h5
# Saved weights to models2/weights_epoch_96400.h5
# Saved weights to models2/weights_epoch_96450.h5
# Saved weights to models2/weights_epoch_96500.h5
# Saved weights to models2/weights_epoch_96550.h5
# Saved weights to models2/weights_epoch_96600.h5
# Saved weights to models2/weights_epoch_96650.h5
# Saved weights to models2/weights_epoch_96700.h5
# Saved weights to models2/weights_epoch_96750.h5
# Saved weights to models2/weights_epoch_96800.h5
# Saved weights to models2/weights_epoch_96850.h5
# Saved weights to models2/weights_epoch_96900.h5
# Saved weights to models2/weights_epoch_96950.h5
# Saved weights to models2/weights_epoch_97000.h5
# Saved weights to models2/weights_epoch_97050.h5
# Saved weights to models2/weights_epoch_97100.h5
# Saved weights to models2/weights_epoch_97150.h5
# Saved weights to models2/weights_epoch_97200.h5
# Saved weights to models2/weights_epoch_97250.h5
# Saved weights to models2/weights_epoch_97300.h5
# Saved weights to models2/weights_epoch_97350.h5
# Saved weights to models2/weights_epoch_97400.h5
# Saved weights to models2/weights_epoch_97450.h5
# Saved weights to models2/weights_epoch_97500.h5
# Saved weights to models2/weights_epoch_97550.h5
# Saved weights to models2/weights_epoch_97600.h5
# Saved weights to models2/weights_epoch_97650.h5
# Saved weights to models2/weights_epoch_97700.h5
# Saved weights to models2/weights_epoch_97750.h5
# Saved weights to models2/weights_epoch_97800.h5
# Saved weights to models2/weights_epoch_97850.h5
# Saved weights to models2/weights_epoch_97900.h5
# Saved weights to models2/weights_epoch_97950.h5
# Saved weights to models2/weights_epoch_98000.h5
# Saved weights to models2/weights_epoch_98050.h5
# Saved weights to models2/weights_epoch_98100.h5
# Saved weights to models2/weights_epoch_98150.h5
# Saved weights to models2/weights_epoch_98200.h5
# Saved weights to models2/weights_epoch_98250.h5
# Saved weights to models2/weights_epoch_98300.h5
# Saved weights to models2/weights_epoch_98350.h5
# Saved weights to models2/weights_epoch_98400.h5
# Saved weights to models2/weights_epoch_98450.h5
# Saved weights to models2/weights_epoch_98500.h5
# Saved weights to models2/weights_epoch_98550.h5
# Saved weights to models2/weights_epoch_98600.h5
# Saved weights to models2/weights_epoch_98650.h5
# Saved weights to models2/weights_epoch_98700.h5
# Saved weights to models2/weights_epoch_98750.h5
# Saved weights to models2/weights_epoch_98800.h5
# Saved weights to models2/weights_epoch_98850.h5
# Saved weights to models2/weights_epoch_98900.h5
# Saved weights to models2/weights_epoch_98950.h5
# Saved weights to models2/weights_epoch_99000.h5
# Saved weights to models2/weights_epoch_99050.h5
# Saved weights to models2/weights_epoch_99100.h5
# Saved weights to models2/weights_epoch_99150.h5
# Saved weights to models2/weights_epoch_99200.h5
# Saved weights to models2/weights_epoch_99250.h5
# Saved weights to models2/weights_epoch_99300.h5
# Saved weights to models2/weights_epoch_99350.h5
# Saved weights to models2/weights_epoch_99400.h5
# Saved weights to models2/weights_epoch_99450.h5
# Saved weights to models2/weights_epoch_99500.h5
# Saved weights to models2/weights_epoch_99550.h5
# Saved weights to models2/weights_epoch_99600.h5
# Saved weights to models2/weights_epoch_99650.h5
# Saved weights to models2/weights_epoch_99700.h5
# Saved weights to models2/weights_epoch_99750.h5
# Saved weights to models2/weights_epoch_99800.h5
# Saved weights to models2/weights_epoch_99850.h5
# Saved weights to models2/weights_epoch_99900.h5
# Saved weights to models2/weights_epoch_99950.h5
# Saved weights to models2/weights_epoch_100000.h5
# Saved weights to models2/weights_epoch_100050.h5
# Saved weights to models2/weights_epoch_100100.h5
# Saved weights to models2/weights_epoch_100150.h5
# Saved weights to models2/weights_epoch_100200.h5
# Saved weights to models2/weights_epoch_100250.h5
# Saved weights to models2/weights_epoch_100300.h5
# Saved weights to models2/weights_epoch_100350.h5
# Saved weights to models2/weights_epoch_100400.h5
# Saved weights to models2/weights_epoch_100450.h5
# Saved weights to models2/weights_epoch_100500.h5
# Saved weights to models2/weights_epoch_100550.h5
# Saved weights to models2/weights_epoch_100600.h5
# Saved weights to models2/weights_epoch_100650.h5
# Saved weights to models2/weights_epoch_100700.h5
# Saved weights to models2/weights_epoch_100750.h5
# Saved weights to models2/weights_epoch_100800.h5
# Saved weights to models2/weights_epoch_100850.h5
# Saved weights to models2/weights_epoch_100900.h5
# Saved weights to models2/weights_epoch_100950.h5
# Saved weights to models2/weights_epoch_101000.h5
# Saved weights to models2/weights_epoch_101050.h5
# Saved weights to models2/weights_epoch_101100.h5
# Saved weights to models2/weights_epoch_101150.h5
# Saved weights to models2/weights_epoch_101200.h5
# Saved weights to models2/weights_epoch_101250.h5
# Saved weights to models2/weights_epoch_101300.h5
# Saved weights to models2/weights_epoch_101350.h5
# Saved weights to models2/weights_epoch_101400.h5
# Saved weights to models2/weights_epoch_101450.h5
# Saved weights to models2/weights_epoch_101500.h5
# Saved weights to models2/weights_epoch_101550.h5
# Saved weights to models2/weights_epoch_101600.h5
# Saved weights to models2/weights_epoch_101650.h5
# Saved weights to models2/weights_epoch_101700.h5
# Saved weights to models2/weights_epoch_101750.h5
# Saved weights to models2/weights_epoch_101800.h5
# Saved weights to models2/weights_epoch_101850.h5
# Saved weights to models2/weights_epoch_101900.h5
# Saved weights to models2/weights_epoch_101950.h5
# Saved weights to models2/weights_epoch_102000.h5
# Saved weights to models2/weights_epoch_102050.h5
# Saved weights to models2/weights_epoch_102100.h5
# Saved weights to models2/weights_epoch_102150.h5
# Saved weights to models2/weights_epoch_102200.h5
# Saved weights to models2/weights_epoch_102250.h5
# Saved weights to models2/weights_epoch_102300.h5
# Saved weights to models2/weights_epoch_102350.h5
# Saved weights to models2/weights_epoch_102400.h5
# Saved weights to models2/weights_epoch_102450.h5
# Saved weights to models2/weights_epoch_102500.h5
# Saved weights to models2/weights_epoch_102550.h5
# Saved weights to models2/weights_epoch_102600.h5
# Saved weights to models2/weights_epoch_102650.h5
# Saved weights to models2/weights_epoch_102700.h5
# Saved weights to models2/weights_epoch_102750.h5
# Saved weights to models2/weights_epoch_102800.h5
# Saved weights to models2/weights_epoch_102850.h5
# Saved weights to models2/weights_epoch_102900.h5
# Saved weights to models2/weights_epoch_102950.h5
# Saved weights to models2/weights_epoch_103000.h5
# Saved weights to models2/weights_epoch_103050.h5
# Saved weights to models2/weights_epoch_103100.h5
# Saved weights to models2/weights_epoch_103150.h5
# Saved weights to models2/weights_epoch_103200.h5
# Saved weights to models2/weights_epoch_103250.h5
# Saved weights to models2/weights_epoch_103300.h5
# Saved weights to models2/weights_epoch_103350.h5
# Saved weights to models2/weights_epoch_103400.h5
# Saved weights to models2/weights_epoch_103450.h5
# Saved weights to models2/weights_epoch_103500.h5
# Saved weights to models2/weights_epoch_103550.h5
# Saved weights to models2/weights_epoch_103600.h5
# Saved weights to models2/weights_epoch_103650.h5
# Saved weights to models2/weights_epoch_103700.h5
# Saved weights to models2/weights_epoch_103750.h5
# Saved weights to models2/weights_epoch_103800.h5
# Saved weights to models2/weights_epoch_103850.h5
# Saved weights to models2/weights_epoch_103900.h5
# Saved weights to models2/weights_epoch_103950.h5
# Saved weights to models2/weights_epoch_104000.h5
# Saved weights to models2/weights_epoch_104050.h5
# Saved weights to models2/weights_epoch_104100.h5
# Saved weights to models2/weights_epoch_104150.h5
# Saved weights to models2/weights_epoch_104200.h5
# Saved weights to models2/weights_epoch_104250.h5
# Saved weights to models2/weights_epoch_104300.h5
# Saved weights to models2/weights_epoch_104350.h5
# Saved weights to models2/weights_epoch_104400.h5
# Saved weights to models2/weights_epoch_104450.h5
# Saved weights to models2/weights_epoch_104500.h5
# Saved weights to models2/weights_epoch_104550.h5
# Saved weights to models2/weights_epoch_104600.h5
# Saved weights to models2/weights_epoch_104650.h5
# Saved weights to models2/weights_epoch_104700.h5
# Saved weights to models2/weights_epoch_104750.h5
# Saved weights to models2/weights_epoch_104800.h5
# Saved weights to models2/weights_epoch_104850.h5
# Saved weights to models2/weights_epoch_104900.h5
# Saved weights to models2/weights_epoch_104950.h5
# Saved weights to models2/weights_epoch_105000.h5
# Saved weights to models2/weights_epoch_105050.h5
# Saved weights to models2/weights_epoch_105100.h5
# Saved weights to models2/weights_epoch_105150.h5
# Saved weights to models2/weights_epoch_105200.h5
# Saved weights to models2/weights_epoch_105250.h5
# Saved weights to models2/weights_epoch_105300.h5
# Saved weights to models2/weights_epoch_105350.h5
# Saved weights to models2/weights_epoch_105400.h5
# Saved weights to models2/weights_epoch_105450.h5
# Saved weights to models2/weights_epoch_105500.h5
# Saved weights to models2/weights_epoch_105550.h5
# Saved weights to models2/weights_epoch_105600.h5
# Saved weights to models2/weights_epoch_105650.h5
# Saved weights to models2/weights_epoch_105700.h5
# Saved weights to models2/weights_epoch_105750.h5
# Saved weights to models2/weights_epoch_105800.h5
# Saved weights to models2/weights_epoch_105850.h5
# Saved weights to models2/weights_epoch_105900.h5
# Saved weights to models2/weights_epoch_105950.h5
# Saved weights to models2/weights_epoch_106000.h5
# Saved weights to models2/weights_epoch_106050.h5
# Saved weights to models2/weights_epoch_106100.h5
# Saved weights to models2/weights_epoch_106150.h5
# Saved weights to models2/weights_epoch_106200.h5
# Saved weights to models2/weights_epoch_106250.h5
# Saved weights to models2/weights_epoch_106300.h5
# Saved weights to models2/weights_epoch_106350.h5
# Saved weights to models2/weights_epoch_106400.h5
# Saved weights to models2/weights_epoch_106450.h5
# Saved weights to models2/weights_epoch_106500.h5
# Saved weights to models2/weights_epoch_106550.h5
# Saved weights to models2/weights_epoch_106600.h5
# Saved weights to models2/weights_epoch_106650.h5
# Saved weights to models2/weights_epoch_106700.h5
# Saved weights to models2/weights_epoch_106750.h5
# Saved weights to models2/weights_epoch_106800.h5
# Saved weights to models2/weights_epoch_106850.h5
# Saved weights to models2/weights_epoch_106900.h5
# Saved weights to models2/weights_epoch_106950.h5
# Saved weights to models2/weights_epoch_107000.h5
# Saved weights to models2/weights_epoch_107050.h5
# Saved weights to models2/weights_epoch_107100.h5
# Saved weights to models2/weights_epoch_107150.h5
# Saved weights to models2/weights_epoch_107200.h5
# Saved weights to models2/weights_epoch_107250.h5
# Saved weights to models2/weights_epoch_107300.h5
# Saved weights to models2/weights_epoch_107350.h5
# Saved weights to models2/weights_epoch_107400.h5
# Saved weights to models2/weights_epoch_107450.h5
# Saved weights to models2/weights_epoch_107500.h5
# Saved weights to models2/weights_epoch_107550.h5
# Saved weights to models2/weights_epoch_107600.h5
# Saved weights to models2/weights_epoch_107650.h5
# Saved weights to models2/weights_epoch_107700.h5
# Saved weights to models2/weights_epoch_107750.h5
# Saved weights to models2/weights_epoch_107800.h5
# Saved weights to models2/weights_epoch_107850.h5
# Saved weights to models2/weights_epoch_107900.h5
# Saved weights to models2/weights_epoch_107950.h5
# Saved weights to models2/weights_epoch_108000.h5
# Saved weights to models2/weights_epoch_108050.h5
# Saved weights to models2/weights_epoch_108100.h5
# Saved weights to models2/weights_epoch_108150.h5
# Saved weights to models2/weights_epoch_108200.h5
# Saved weights to models2/weights_epoch_108250.h5
# Saved weights to models2/weights_epoch_108300.h5
# Saved weights to models2/weights_epoch_108350.h5
# Saved weights to models2/weights_epoch_108400.h5
# Saved weights to models2/weights_epoch_108450.h5
# Saved weights to models2/weights_epoch_108500.h5
# Saved weights to models2/weights_epoch_108550.h5
# Saved weights to models2/weights_epoch_108600.h5
# Saved weights to models2/weights_epoch_108650.h5
# Saved weights to models2/weights_epoch_108700.h5
# Saved weights to models2/weights_epoch_108750.h5
# Saved weights to models2/weights_epoch_108800.h5
# Saved weights to models2/weights_epoch_108850.h5
# Saved weights to models2/weights_epoch_108900.h5
# Saved weights to models2/weights_epoch_108950.h5
# Saved weights to models2/weights_epoch_109000.h5
# Saved weights to models2/weights_epoch_109050.h5
# Saved weights to models2/weights_epoch_109100.h5
# Saved weights to models2/weights_epoch_109150.h5
# Saved weights to models2/weights_epoch_109200.h5
# Saved weights to models2/weights_epoch_109250.h5
# Saved weights to models2/weights_epoch_109300.h5
# Saved weights to models2/weights_epoch_109350.h5
# Saved weights to models2/weights_epoch_109400.h5
# Saved weights to models2/weights_epoch_109450.h5
# Saved weights to models2/weights_epoch_109500.h5
# Saved weights to models2/weights_epoch_109550.h5
# Saved weights to models2/weights_epoch_109600.h5
# Saved weights to models2/weights_epoch_109650.h5
# Saved weights to models2/weights_epoch_109700.h5
# Saved weights to models2/weights_epoch_109750.h5
# Saved weights to models2/weights_epoch_109800.h5
# Saved weights to models2/weights_epoch_109850.h5
# Saved weights to models2/weights_epoch_109900.h5
# Saved weights to models2/weights_epoch_109950.h5
# Saved weights to models2/weights_epoch_110000.h5
# Saved weights to models2/weights_epoch_110050.h5
# Saved weights to models2/weights_epoch_110100.h5
# Saved weights to models2/weights_epoch_110150.h5
# Saved weights to models2/weights_epoch_110200.h5
# Saved weights to models2/weights_epoch_110250.h5
# Saved weights to models2/weights_epoch_110300.h5
# Saved weights to models2/weights_epoch_110350.h5
# Saved weights to models2/weights_epoch_110400.h5
# Saved weights to models2/weights_epoch_110450.h5
# Saved weights to models2/weights_epoch_110500.h5
# Saved weights to models2/weights_epoch_110550.h5
# Saved weights to models2/weights_epoch_110600.h5
# Saved weights to models2/weights_epoch_110650.h5
# Saved weights to models2/weights_epoch_110700.h5
# Saved weights to models2/weights_epoch_110750.h5
# Saved weights to models2/weights_epoch_110800.h5
# Saved weights to models2/weights_epoch_110850.h5
# Saved weights to models2/weights_epoch_110900.h5
# Saved weights to models2/weights_epoch_110950.h5
# Saved weights to models2/weights_epoch_111000.h5
# Saved weights to models2/weights_epoch_111050.h5
# Saved weights to models2/weights_epoch_111100.h5
# Saved weights to models2/weights_epoch_111150.h5
# Saved weights to models2/weights_epoch_111200.h5
# Saved weights to models2/weights_epoch_111250.h5
# Saved weights to models2/weights_epoch_111300.h5
# Saved weights to models2/weights_epoch_111350.h5
# Saved weights to models2/weights_epoch_111400.h5
# Saved weights to models2/weights_epoch_111450.h5
# Saved weights to models2/weights_epoch_111500.h5
# Saved weights to models2/weights_epoch_111550.h5
# Saved weights to models2/weights_epoch_111600.h5
# Saved weights to models2/weights_epoch_111650.h5
# Saved weights to models2/weights_epoch_111700.h5
# Saved weights to models2/weights_epoch_111750.h5
# Saved weights to models2/weights_epoch_111800.h5
# Saved weights to models2/weights_epoch_111850.h5
# Saved weights to models2/weights_epoch_111900.h5
# Saved weights to models2/weights_epoch_111950.h5
# Saved weights to models2/weights_epoch_112000.h5
# Saved weights to models2/weights_epoch_112050.h5
# Saved weights to models2/weights_epoch_112100.h5
# Saved weights to models2/weights_epoch_112150.h5
# Saved weights to models2/weights_epoch_112200.h5
# Saved weights to models2/weights_epoch_112250.h5
# Saved weights to models2/weights_epoch_112300.h5
# Saved weights to models2/weights_epoch_112350.h5
# Saved weights to models2/weights_epoch_112400.h5
# Saved weights to models2/weights_epoch_112450.h5
# Saved weights to models2/weights_epoch_112500.h5
# Saved weights to models2/weights_epoch_112550.h5
# Saved weights to models2/weights_epoch_112600.h5
# Saved weights to models2/weights_epoch_112650.h5
# Saved weights to models2/weights_epoch_112700.h5
# Saved weights to models2/weights_epoch_112750.h5
# Saved weights to models2/weights_epoch_112800.h5
# Saved weights to models2/weights_epoch_112850.h5
# Saved weights to models2/weights_epoch_112900.h5
# Saved weights to models2/weights_epoch_112950.h5
# Saved weights to models2/weights_epoch_113000.h5
# Saved weights to models2/weights_epoch_113050.h5
# Saved weights to models2/weights_epoch_113100.h5
# Saved weights to models2/weights_epoch_113150.h5
# Saved weights to models2/weights_epoch_113200.h5
# Saved weights to models2/weights_epoch_113250.h5
# Saved weights to models2/weights_epoch_113300.h5
# Saved weights to models2/weights_epoch_113350.h5
# Saved weights to models2/weights_epoch_113400.h5
# Saved weights to models2/weights_epoch_113450.h5
# Saved weights to models2/weights_epoch_113500.h5
# Saved weights to models2/weights_epoch_113550.h5
# Saved weights to models2/weights_epoch_113600.h5
# Saved weights to models2/weights_epoch_113650.h5
# Saved weights to models2/weights_epoch_113700.h5
# Saved weights to models2/weights_epoch_113750.h5
# Saved weights to models2/weights_epoch_113800.h5
# Saved weights to models2/weights_epoch_113850.h5
# Saved weights to models2/weights_epoch_113900.h5
# Saved weights to models2/weights_epoch_113950.h5
# Saved weights to models2/weights_epoch_114000.h5
# Saved weights to models2/weights_epoch_114050.h5
# Saved weights to models2/weights_epoch_114100.h5
# Saved weights to models2/weights_epoch_114150.h5
# Saved weights to models2/weights_epoch_114200.h5
# Saved weights to models2/weights_epoch_114250.h5
# Saved weights to models2/weights_epoch_114300.h5
# Saved weights to models2/weights_epoch_114350.h5
# Saved weights to models2/weights_epoch_114400.h5
# Saved weights to models2/weights_epoch_114450.h5
# Saved weights to models2/weights_epoch_114500.h5
# Saved weights to models2/weights_epoch_114550.h5
# Saved weights to models2/weights_epoch_114600.h5
# Saved weights to models2/weights_epoch_114650.h5
# Saved weights to models2/weights_epoch_114700.h5
# Saved weights to models2/weights_epoch_114750.h5
# Saved weights to models2/weights_epoch_114800.h5
# Saved weights to models2/weights_epoch_114850.h5
# Saved weights to models2/weights_epoch_114900.h5
# Saved weights to models2/weights_epoch_114950.h5
# Saved weights to models2/weights_epoch_115000.h5
# Saved weights to models2/weights_epoch_115050.h5
# Saved weights to models2/weights_epoch_115100.h5
# Saved weights to models2/weights_epoch_115150.h5
# Saved weights to models2/weights_epoch_115200.h5
# Saved weights to models2/weights_epoch_115250.h5
# Saved weights to models2/weights_epoch_115300.h5
# Saved weights to models2/weights_epoch_115350.h5
# Saved weights to models2/weights_epoch_115400.h5
# Saved weights to models2/weights_epoch_115450.h5
# Saved weights to models2/weights_epoch_115500.h5
# Saved weights to models2/weights_epoch_115550.h5
# Saved weights to models2/weights_epoch_115600.h5
# Saved weights to models2/weights_epoch_115650.h5
# Saved weights to models2/weights_epoch_115700.h5
# Saved weights to models2/weights_epoch_115750.h5
# Saved weights to models2/weights_epoch_115800.h5
# Saved weights to models2/weights_epoch_115850.h5
# Saved weights to models2/weights_epoch_115900.h5
# Saved weights to models2/weights_epoch_115950.h5
# Saved weights to models2/weights_epoch_116000.h5
# Saved weights to models2/weights_epoch_116050.h5
# Saved weights to models2/weights_epoch_116100.h5
# Saved weights to models2/weights_epoch_116150.h5
# Saved weights to models2/weights_epoch_116200.h5
# Saved weights to models2/weights_epoch_116250.h5
# Saved weights to models2/weights_epoch_116300.h5
# Saved weights to models2/weights_epoch_116350.h5
# Saved weights to models2/weights_epoch_116400.h5
# Saved weights to models2/weights_epoch_116450.h5
# Saved weights to models2/weights_epoch_116500.h5
# Saved weights to models2/weights_epoch_116550.h5
# Saved weights to models2/weights_epoch_116600.h5
# Saved weights to models2/weights_epoch_116650.h5
# Saved weights to models2/weights_epoch_116700.h5
# Saved weights to models2/weights_epoch_116750.h5
# Saved weights to models2/weights_epoch_116800.h5
# Saved weights to models2/weights_epoch_116850.h5
# Saved weights to models2/weights_epoch_116900.h5
# Saved weights to models2/weights_epoch_116950.h5
# Saved weights to models2/weights_epoch_117000.h5
# Saved weights to models2/weights_epoch_117050.h5
# Saved weights to models2/weights_epoch_117100.h5
# Saved weights to models2/weights_epoch_117150.h5
# Saved weights to models2/weights_epoch_117200.h5
# Saved weights to models2/weights_epoch_117250.h5
# Saved weights to models2/weights_epoch_117300.h5
# Saved weights to models2/weights_epoch_117350.h5
# Saved weights to models2/weights_epoch_117400.h5
# Saved weights to models2/weights_epoch_117450.h5
# Saved weights to models2/weights_epoch_117500.h5
# Saved weights to models2/weights_epoch_117550.h5
# Saved weights to models2/weights_epoch_117600.h5
# Saved weights to models2/weights_epoch_117650.h5
# Saved weights to models2/weights_epoch_117700.h5
# Saved weights to models2/weights_epoch_117750.h5
# Saved weights to models2/weights_epoch_117800.h5
# Saved weights to models2/weights_epoch_117850.h5
# Saved weights to models2/weights_epoch_117900.h5
# Saved weights to models2/weights_epoch_117950.h5
# Saved weights to models2/weights_epoch_118000.h5
# Saved weights to models2/weights_epoch_118050.h5
# Saved weights to models2/weights_epoch_118100.h5
# Saved weights to models2/weights_epoch_118150.h5
# Saved weights to models2/weights_epoch_118200.h5
# Saved weights to models2/weights_epoch_118250.h5
# Saved weights to models2/weights_epoch_118300.h5
# Saved weights to models2/weights_epoch_118350.h5
# Saved weights to models2/weights_epoch_118400.h5
# Saved weights to models2/weights_epoch_118450.h5
# Saved weights to models2/weights_epoch_118500.h5
# Saved weights to models2/weights_epoch_118550.h5
# Saved weights to models2/weights_epoch_118600.h5
# Saved weights to models2/weights_epoch_118650.h5
# Saved weights to models2/weights_epoch_118700.h5
# Saved weights to models2/weights_epoch_118750.h5
# Saved weights to models2/weights_epoch_118800.h5
# Saved weights to models2/weights_epoch_118850.h5
# Saved weights to models2/weights_epoch_118900.h5
# Saved weights to models2/weights_epoch_118950.h5
# Saved weights to models2/weights_epoch_119000.h5
# Saved weights to models2/weights_epoch_119050.h5
# Saved weights to models2/weights_epoch_119100.h5
# Saved weights to models2/weights_epoch_119150.h5
# Saved weights to models2/weights_epoch_119200.h5
# Saved weights to models2/weights_epoch_119250.h5
# Saved weights to models2/weights_epoch_119300.h5
# Saved weights to models2/weights_epoch_119350.h5
# Saved weights to models2/weights_epoch_119400.h5
# Saved weights to models2/weights_epoch_119450.h5
# Saved weights to models2/weights_epoch_119500.h5
# Saved weights to models2/weights_epoch_119550.h5
# Saved weights to models2/weights_epoch_119600.h5
# Saved weights to models2/weights_epoch_119650.h5
# Saved weights to models2/weights_epoch_119700.h5
# Saved weights to models2/weights_epoch_119750.h5
# Saved weights to models2/weights_epoch_119800.h5
# Saved weights to models2/weights_epoch_119850.h5
# Saved weights to models2/weights_epoch_119900.h5
# Saved weights to models2/weights_epoch_119950.h5
# Saved weights to models2/weights_epoch_120000.h5
# Saved weights to models2/weights_epoch_120050.h5
# Saved weights to models2/weights_epoch_120100.h5
# Saved weights to models2/weights_epoch_120150.h5
# Saved weights to models2/weights_epoch_120200.h5
# Saved weights to models2/weights_epoch_120250.h5
# Saved weights to models2/weights_epoch_120300.h5
# Saved weights to models2/weights_epoch_120350.h5
# Saved weights to models2/weights_epoch_120400.h5
# Saved weights to models2/weights_epoch_120450.h5
# Saved weights to models2/weights_epoch_120500.h5
# Saved weights to models2/weights_epoch_120550.h5
# Saved weights to models2/weights_epoch_120600.h5
# Saved weights to models2/weights_epoch_120650.h5
# Saved weights to models2/weights_epoch_120700.h5
# Saved weights to models2/weights_epoch_120750.h5
# Saved weights to models2/weights_epoch_120800.h5
# Saved weights to models2/weights_epoch_120850.h5
# Saved weights to models2/weights_epoch_120900.h5
# Saved weights to models2/weights_epoch_120950.h5
# Saved weights to models2/weights_epoch_121000.h5
# Saved weights to models2/weights_epoch_121050.h5
# Saved weights to models2/weights_epoch_121100.h5
# Saved weights to models2/weights_epoch_121150.h5
# Saved weights to models2/weights_epoch_121200.h5
# Saved weights to models2/weights_epoch_121250.h5
# Saved weights to models2/weights_epoch_121300.h5
# Saved weights to models2/weights_epoch_121350.h5
# Saved weights to models2/weights_epoch_121400.h5
# Saved weights to models2/weights_epoch_121450.h5
# Saved weights to models2/weights_epoch_121500.h5
# Saved weights to models2/weights_epoch_121550.h5
# Saved weights to models2/weights_epoch_121600.h5
# Saved weights to models2/weights_epoch_121650.h5
# Saved weights to models2/weights_epoch_121700.h5
# Saved weights to models2/weights_epoch_121750.h5
# Saved weights to models2/weights_epoch_121800.h5
# Saved weights to models2/weights_epoch_121850.h5
# Saved weights to models2/weights_epoch_121900.h5
# Saved weights to models2/weights_epoch_121950.h5
# Saved weights to models2/weights_epoch_122000.h5
# Saved weights to models2/weights_epoch_122050.h5
# Saved weights to models2/weights_epoch_122100.h5
# Saved weights to models2/weights_epoch_122150.h5
# Saved weights to models2/weights_epoch_122200.h5
# Saved weights to models2/weights_epoch_122250.h5
# Saved weights to models2/weights_epoch_122300.h5
# Saved weights to models2/weights_epoch_122350.h5
# Saved weights to models2/weights_epoch_122400.h5
# Saved weights to models2/weights_epoch_122450.h5
# Saved weights to models2/weights_epoch_122500.h5
# Saved weights to models2/weights_epoch_122550.h5
# Saved weights to models2/weights_epoch_122600.h5
# Saved weights to models2/weights_epoch_122650.h5
# Saved weights to models2/weights_epoch_122700.h5
# Saved weights to models2/weights_epoch_122750.h5
# Saved weights to models2/weights_epoch_122800.h5
# Saved weights to models2/weights_epoch_122850.h5
# Saved weights to models2/weights_epoch_122900.h5
# Saved weights to models2/weights_epoch_122950.h5
# Saved weights to models2/weights_epoch_123000.h5
# Saved weights to models2/weights_epoch_123050.h5
# Saved weights to models2/weights_epoch_123100.h5
# Saved weights to models2/weights_epoch_123150.h5
# Saved weights to models2/weights_epoch_123200.h5
# Saved weights to models2/weights_epoch_123250.h5
# Saved weights to models2/weights_epoch_123300.h5
# Saved weights to models2/weights_epoch_123350.h5
# Saved weights to models2/weights_epoch_123400.h5
# Saved weights to models2/weights_epoch_123450.h5
# Saved weights to models2/weights_epoch_123500.h5
# Saved weights to models2/weights_epoch_123550.h5
# Saved weights to models2/weights_epoch_123600.h5
# Saved weights to models2/weights_epoch_123650.h5
# Saved weights to models2/weights_epoch_123700.h5
# Saved weights to models2/weights_epoch_123750.h5
# Saved weights to models2/weights_epoch_123800.h5
# Saved weights to models2/weights_epoch_123850.h5
# Saved weights to models2/weights_epoch_123900.h5
# Saved weights to models2/weights_epoch_123950.h5
# Saved weights to models2/weights_epoch_124000.h5
# Saved weights to models2/weights_epoch_124050.h5
# Saved weights to models2/weights_epoch_124100.h5
# Saved weights to models2/weights_epoch_124150.h5
# Saved weights to models2/weights_epoch_124200.h5
# Saved weights to models2/weights_epoch_124250.h5
# Saved weights to models2/weights_epoch_124300.h5
# Saved weights to models2/weights_epoch_124350.h5
# Saved weights to models2/weights_epoch_124400.h5
# Saved weights to models2/weights_epoch_124450.h5
# Saved weights to models2/weights_epoch_124500.h5
# Saved weights to models2/weights_epoch_124550.h5
# Saved weights to models2/weights_epoch_124600.h5
# Saved weights to models2/weights_epoch_124650.h5
# Saved weights to models2/weights_epoch_124700.h5
# Saved weights to models2/weights_epoch_124750.h5
# Saved weights to models2/weights_epoch_124800.h5
# Saved weights to models2/weights_epoch_124850.h5
# Saved weights to models2/weights_epoch_124900.h5
# Saved weights to models2/weights_epoch_124950.h5
# Saved weights to models2/weights_epoch_125000.h5
# Saved weights to models2/weights_epoch_125050.h5
# Saved weights to models2/weights_epoch_125100.h5
# Saved weights to models2/weights_epoch_125150.h5
# Saved weights to models2/weights_epoch_125200.h5
# Saved weights to models2/weights_epoch_125250.h5
# Saved weights to models2/weights_epoch_125300.h5
# Saved weights to models2/weights_epoch_125350.h5
# Saved weights to models2/weights_epoch_125400.h5
# Saved weights to models2/weights_epoch_125450.h5
# Saved weights to models2/weights_epoch_125500.h5
# Saved weights to models2/weights_epoch_125550.h5
# Saved weights to models2/weights_epoch_125600.h5
# Saved weights to models2/weights_epoch_125650.h5
# Saved weights to models2/weights_epoch_125700.h5
# Saved weights to models2/weights_epoch_125750.h5
# Saved weights to models2/weights_epoch_125800.h5
# Saved weights to models2/weights_epoch_125850.h5
# Saved weights to models2/weights_epoch_125900.h5
# Saved weights to models2/weights_epoch_125950.h5
# Saved weights to models2/weights_epoch_126000.h5
# Saved weights to models2/weights_epoch_126050.h5
# Saved weights to models2/weights_epoch_126100.h5
# Saved weights to models2/weights_epoch_126150.h5
# Saved weights to models2/weights_epoch_126200.h5
# Saved weights to models2/weights_epoch_126250.h5
# Saved weights to models2/weights_epoch_126300.h5
# Saved weights to models2/weights_epoch_126350.h5
# Saved weights to models2/weights_epoch_126400.h5
# Saved weights to models2/weights_epoch_126450.h5
# Saved weights to models2/weights_epoch_126500.h5
# Saved weights to models2/weights_epoch_126550.h5
# Saved weights to models2/weights_epoch_126600.h5
# Saved weights to models2/weights_epoch_126650.h5
# Saved weights to models2/weights_epoch_126700.h5
# Saved weights to models2/weights_epoch_126750.h5
# Saved weights to models2/weights_epoch_126800.h5
# Saved weights to models2/weights_epoch_126850.h5
# Saved weights to models2/weights_epoch_126900.h5
# Saved weights to models2/weights_epoch_126950.h5
# Saved weights to models2/weights_epoch_127000.h5
# Saved weights to models2/weights_epoch_127050.h5
# Saved weights to models2/weights_epoch_127100.h5
# Saved weights to models2/weights_epoch_127150.h5
# Saved weights to models2/weights_epoch_127200.h5
# Saved weights to models2/weights_epoch_127250.h5
# Saved weights to models2/weights_epoch_127300.h5
# Saved weights to models2/weights_epoch_127350.h5
# Saved weights to models2/weights_epoch_127400.h5
# Saved weights to models2/weights_epoch_127450.h5
# Saved weights to models2/weights_epoch_127500.h5
# Saved weights to models2/weights_epoch_127550.h5
# Saved weights to models2/weights_epoch_127600.h5
# Saved weights to models2/weights_epoch_127650.h5
# Saved weights to models2/weights_epoch_127700.h5
# Saved weights to models2/weights_epoch_127750.h5
# Saved weights to models2/weights_epoch_127800.h5
# Saved weights to models2/weights_epoch_127850.h5
# Saved weights to models2/weights_epoch_127900.h5
# Saved weights to models2/weights_epoch_127950.h5
# Saved weights to models2/weights_epoch_128000.h5
# ...
# Saved weights to models2/weights_epoch_193100.h5
# Saved weights to models2/weights_epoch_193150.h5
# Saved weights to models2/weights_epoch_193200.h5
# Saved weights to models2/weights_epoch_193250.h5
# Saved weights to models2/weights_epoch_193300.h5
# Saved weights to models2/weights_epoch_193350.h5
# Saved weights to models2/weights_epoch_193400.h5
# Saved weights to models2/weights_epoch_193450.h5
# Saved weights to models2/weights_epoch_193500.h5
# Saved weights to models2/weights_epoch_193550.h5
# Saved weights to models2/weights_epoch_193600.h5
# Saved weights to models2/weights_epoch_193650.h5
# Saved weights to models2/weights_epoch_193700.h5
# Saved weights to models2/weights_epoch_193750.h5
# Saved weights to models2/weights_epoch_193800.h5
# Saved weights to models2/weights_epoch_193850.h5
# Saved weights to models2/weights_epoch_193900.h5
# Saved weights to models2/weights_epoch_193950.h5
# Saved weights to models2/weights_epoch_194000.h5
# Saved weights to models2/weights_epoch_194050.h5
# Saved weights to models2/weights_epoch_194100.h5
# Saved weights to models2/weights_epoch_194150.h5
# Saved weights to models2/weights_epoch_194200.h5
# Saved weights to models2/weights_epoch_194250.h5
# Saved weights to models2/weights_epoch_194300.h5
# Saved weights to models2/weights_epoch_194350.h5
# Saved weights to models2/weights_epoch_194400.h5
# Saved weights to models2/weights_epoch_194450.h5
# Saved weights to models2/weights_epoch_194500.h5
# Saved weights to models2/weights_epoch_194550.h5
# Saved weights to models2/weights_epoch_194600.h5
# Saved weights to models2/weights_epoch_194650.h5
# Saved weights to models2/weights_epoch_194700.h5
# Saved weights to models2/weights_epoch_194750.h5
# Saved weights to models2/weights_epoch_194800.h5
# Saved weights to models2/weights_epoch_194850.h5
# Saved weights to models2/weights_epoch_194900.h5
# Saved weights to models2/weights_epoch_194950.h5
# Saved weights to models2/weights_epoch_195000.h5
# Saved weights to models2/weights_epoch_195050.h5
# Saved weights to models2/weights_epoch_195100.h5
# Saved weights to models2/weights_epoch_195150.h5
# Saved weights to models2/weights_epoch_195200.h5
# Saved weights to models2/weights_epoch_195250.h5
# Saved weights to models2/weights_epoch_195300.h5
# Saved weights to models2/weights_epoch_195350.h5
# Saved weights to models2/weights_epoch_195400.h5
# Saved weights to models2/weights_epoch_195450.h5
# Saved weights to models2/weights_epoch_195500.h5
# Saved weights to models2/weights_epoch_195550.h5
# Saved weights to models2/weights_epoch_195600.h5
# Saved weights to models2/weights_epoch_195650.h5
# Saved weights to models2/weights_epoch_195700.h5
# Saved weights to models2/weights_epoch_195750.h5
# Saved weights to models2/weights_epoch_195800.h5
# Saved weights to models2/weights_epoch_195850.h5
# Saved weights to models2/weights_epoch_195900.h5
# Saved weights to models2/weights_epoch_195950.h5
# Saved weights to models2/weights_epoch_196000.h5
# Saved weights to models2/weights_epoch_196050.h5
# Saved weights to models2/weights_epoch_196100.h5
# Saved weights to models2/weights_epoch_196150.h5
# Saved weights to models2/weights_epoch_196200.h5
# Saved weights to models2/weights_epoch_196250.h5
# Saved weights to models2/weights_epoch_196300.h5
# Saved weights to models2/weights_epoch_196350.h5
# Saved weights to models2/weights_epoch_196400.h5
# Saved weights to models2/weights_epoch_196450.h5
# Saved weights to models2/weights_epoch_196500.h5
# Saved weights to models2/weights_epoch_196550.h5
# Saved weights to models2/weights_epoch_196600.h5
# Saved weights to models2/weights_epoch_196650.h5
# Saved weights to models2/weights_epoch_196700.h5
# Saved weights to models2/weights_epoch_196750.h5
# Saved weights to models2/weights_epoch_196800.h5
# Saved weights to models2/weights_epoch_196850.h5
# Saved weights to models2/weights_epoch_196900.h5
# Saved weights to models2/weights_epoch_196950.h5
# Saved weights to models2/weights_epoch_197000.h5
# Saved weights to models2/weights_epoch_197050.h5
# Saved weights to models2/weights_epoch_197100.h5
# Saved weights to models2/weights_epoch_197150.h5
# Saved weights to models2/weights_epoch_197200.h5
# Saved weights to models2/weights_epoch_197250.h5
# Saved weights to models2/weights_epoch_197300.h5
# Saved weights to models2/weights_epoch_197350.h5
# Saved weights to models2/weights_epoch_197400.h5
# Saved weights to models2/weights_epoch_197450.h5
# Saved weights to models2/weights_epoch_197500.h5
# Saved weights to models2/weights_epoch_197550.h5
# Saved weights to models2/weights_epoch_197600.h5
# Saved weights to models2/weights_epoch_197650.h5
# Saved weights to models2/weights_epoch_197700.h5
# Saved weights to models2/weights_epoch_197750.h5
# Saved weights to models2/weights_epoch_197800.h5
# Saved weights to models2/weights_epoch_197850.h5
# Saved weights to models2/weights_epoch_197900.h5
# Saved weights to models2/weights_epoch_197950.h5
# Saved weights to models2/weights_epoch_198000.h5
# Saved weights to models2/weights_epoch_198050.h5
# Saved weights to models2/weights_epoch_198100.h5
# Saved weights to models2/weights_epoch_198150.h5
# Saved weights to models2/weights_epoch_198200.h5
# Saved weights to models2/weights_epoch_198250.h5
# Saved weights to models2/weights_epoch_198300.h5
# Saved weights to models2/weights_epoch_198350.h5
# Saved weights to models2/weights_epoch_198400.h5
# Saved weights to models2/weights_epoch_198450.h5
# Saved weights to models2/weights_epoch_198500.h5
# Saved weights to models2/weights_epoch_198550.h5
# Saved weights to models2/weights_epoch_198600.h5
# Saved weights to models2/weights_epoch_198650.h5
# Saved weights to models2/weights_epoch_198700.h5
# Saved weights to models2/weights_epoch_198750.h5
# Saved weights to models2/weights_epoch_198800.h5
# Saved weights to models2/weights_epoch_198850.h5
# Saved weights to models2/weights_epoch_198900.h5
# Saved weights to models2/weights_epoch_198950.h5
# Saved weights to models2/weights_epoch_199000.h5
# Saved weights to models2/weights_epoch_199050.h5
# Saved weights to models2/weights_epoch_199100.h5
# Saved weights to models2/weights_epoch_199150.h5
# Saved weights to models2/weights_epoch_199200.h5
# Saved weights to models2/weights_epoch_199250.h5
# Saved weights to models2/weights_epoch_199300.h5
# Saved weights to models2/weights_epoch_199350.h5
# Saved weights to models2/weights_epoch_199400.h5
# Saved weights to models2/weights_epoch_199450.h5
# Saved weights to models2/weights_epoch_199500.h5
# Saved weights to models2/weights_epoch_199550.h5
# Saved weights to models2/weights_epoch_199600.h5
# Saved weights to models2/weights_epoch_199650.h5
# Saved weights to models2/weights_epoch_199700.h5
# Saved weights to models2/weights_epoch_199750.h5
# Saved weights to models2/weights_epoch_199800.h5
# Saved weights to models2/weights_epoch_199850.h5
# Saved weights to models2/weights_epoch_199900.h5
# Saved weights to models2/weights_epoch_199950.h5
# Saved weights to models2/weights_epoch_200000.h5
# Saved weights to models2/weights_epoch_200050.h5
# Saved weights to models2/weights_epoch_200100.h5
# Saved weights to models2/weights_epoch_200150.h5
# Saved weights to models2/weights_epoch_200200.h5
# Saved weights to models2/weights_epoch_200250.h5
# Saved weights to models2/weights_epoch_200300.h5
# Saved weights to models2/weights_epoch_200350.h5
# Saved weights to models2/weights_epoch_200400.h5
# Saved weights to models2/weights_epoch_200450.h5
# Saved weights to models2/weights_epoch_200500.h5
# Saved weights to models2/weights_epoch_200550.h5
# Saved weights to models2/weights_epoch_200600.h5
# Saved weights to models2/weights_epoch_200650.h5
# Saved weights to models2/weights_epoch_200700.h5
# Saved weights to models2/weights_epoch_200750.h5
# Saved weights to models2/weights_epoch_200800.h5
# Saved weights to models2/weights_epoch_200850.h5
# Saved weights to models2/weights_epoch_200900.h5
# Saved weights to models2/weights_epoch_200950.h5
# Saved weights to models2/weights_epoch_201000.h5
# Saved weights to models2/weights_epoch_201050.h5
# Saved weights to models2/weights_epoch_201100.h5
# Saved weights to models2/weights_epoch_201150.h5
# Saved weights to models2/weights_epoch_201200.h5
# Saved weights to models2/weights_epoch_201250.h5
# Saved weights to models2/weights_epoch_201300.h5
# Saved weights to models2/weights_epoch_201350.h5
# Saved weights to models2/weights_epoch_201400.h5
# Saved weights to models2/weights_epoch_201450.h5
# Saved weights to models2/weights_epoch_201500.h5
# Saved weights to models2/weights_epoch_201550.h5
# Saved weights to models2/weights_epoch_201600.h5
# Saved weights to models2/weights_epoch_201650.h5
# Saved weights to models2/weights_epoch_201700.h5
# Saved weights to models2/weights_epoch_201750.h5
# Saved weights to models2/weights_epoch_201800.h5
# Saved weights to models2/weights_epoch_201850.h5
# Saved weights to models2/weights_epoch_201900.h5
# Saved weights to models2/weights_epoch_201950.h5
# Saved weights to models2/weights_epoch_202000.h5
# Saved weights to models2/weights_epoch_202050.h5
# Saved weights to models2/weights_epoch_202100.h5
# Saved weights to models2/weights_epoch_202150.h5
# Saved weights to models2/weights_epoch_202200.h5
# Saved weights to models2/weights_epoch_202250.h5
# Saved weights to models2/weights_epoch_202300.h5
# Saved weights to models2/weights_epoch_202350.h5
# Saved weights to models2/weights_epoch_202400.h5
# Saved weights to models2/weights_epoch_202450.h5
# Saved weights to models2/weights_epoch_202500.h5
# Saved weights to models2/weights_epoch_202550.h5
# Saved weights to models2/weights_epoch_202600.h5
# Saved weights to models2/weights_epoch_202650.h5
# Saved weights to models2/weights_epoch_202700.h5
# Saved weights to models2/weights_epoch_202750.h5
# Saved weights to models2/weights_epoch_202800.h5
# Saved weights to models2/weights_epoch_202850.h5
# Saved weights to models2/weights_epoch_202900.h5
# Saved weights to models2/weights_epoch_202950.h5
# Saved weights to models2/weights_epoch_203000.h5
# Saved weights to models2/weights_epoch_203050.h5
# Saved weights to models2/weights_epoch_203100.h5
# Saved weights to models2/weights_epoch_203150.h5
# Saved weights to models2/weights_epoch_203200.h5
# Saved weights to models2/weights_epoch_203250.h5
# Saved weights to models2/weights_epoch_203300.h5
# Saved weights to models2/weights_epoch_203350.h5
# Saved weights to models2/weights_epoch_203400.h5
# Saved weights to models2/weights_epoch_203450.h5
# Saved weights to models2/weights_epoch_203500.h5
# Saved weights to models2/weights_epoch_203550.h5
# Saved weights to models2/weights_epoch_203600.h5
# Saved weights to models2/weights_epoch_203650.h5
# Saved weights to models2/weights_epoch_203700.h5
# Saved weights to models2/weights_epoch_203750.h5
# Saved weights to models2/weights_epoch_203800.h5
# Saved weights to models2/weights_epoch_203850.h5
# Saved weights to models2/weights_epoch_203900.h5
# Saved weights to models2/weights_epoch_203950.h5
# Saved weights to models2/weights_epoch_204000.h5
# Saved weights to models2/weights_epoch_204050.h5
# Saved weights to models2/weights_epoch_204100.h5
# Saved weights to models2/weights_epoch_204150.h5
# Saved weights to models2/weights_epoch_204200.h5
# Saved weights to models2/weights_epoch_204250.h5
# Saved weights to models2/weights_epoch_204300.h5
# Saved weights to models2/weights_epoch_204350.h5
# Saved weights to models2/weights_epoch_204400.h5
# Saved weights to models2/weights_epoch_204450.h5
# Saved weights to models2/weights_epoch_204500.h5
# Saved weights to models2/weights_epoch_204550.h5
# Saved weights to models2/weights_epoch_204600.h5
# Saved weights to models2/weights_epoch_204650.h5
# Saved weights to models2/weights_epoch_204700.h5
# Saved weights to models2/weights_epoch_204750.h5
# Saved weights to models2/weights_epoch_204800.h5
# Saved weights to models2/weights_epoch_204850.h5
# Saved weights to models2/weights_epoch_204900.h5
# Saved weights to models2/weights_epoch_204950.h5
# Saved weights to models2/weights_epoch_205000.h5
# Saved weights to models2/weights_epoch_205050.h5
# Saved weights to models2/weights_epoch_205100.h5
# Saved weights to models2/weights_epoch_205150.h5
# Saved weights to models2/weights_epoch_205200.h5
# Saved weights to models2/weights_epoch_205250.h5
# Saved weights to models2/weights_epoch_205300.h5
# Saved weights to models2/weights_epoch_205350.h5
# Saved weights to models2/weights_epoch_205400.h5
# Saved weights to models2/weights_epoch_205450.h5
# Saved weights to models2/weights_epoch_205500.h5
# Saved weights to models2/weights_epoch_205550.h5
# Saved weights to models2/weights_epoch_205600.h5
# Saved weights to models2/weights_epoch_205650.h5
# Saved weights to models2/weights_epoch_205700.h5
# Saved weights to models2/weights_epoch_205750.h5
# Saved weights to models2/weights_epoch_205800.h5
# Saved weights to models2/weights_epoch_205850.h5
# Saved weights to models2/weights_epoch_205900.h5
# Saved weights to models2/weights_epoch_205950.h5
# Saved weights to models2/weights_epoch_206000.h5
# Saved weights to models2/weights_epoch_206050.h5
# Saved weights to models2/weights_epoch_206100.h5
# Saved weights to models2/weights_epoch_206150.h5
# Saved weights to models2/weights_epoch_206200.h5
# Saved weights to models2/weights_epoch_206250.h5
# Saved weights to models2/weights_epoch_206300.h5
# Saved weights to models2/weights_epoch_206350.h5
# Saved weights to models2/weights_epoch_206400.h5
# Saved weights to models2/weights_epoch_206450.h5
# Saved weights to models2/weights_epoch_206500.h5
# Saved weights to models2/weights_epoch_206550.h5
# Saved weights to models2/weights_epoch_206600.h5
# Saved weights to models2/weights_epoch_206650.h5
# Saved weights to models2/weights_epoch_206700.h5
# Saved weights to models2/weights_epoch_206750.h5
# Saved weights to models2/weights_epoch_206800.h5
# Saved weights to models2/weights_epoch_206850.h5
# Saved weights to models2/weights_epoch_206900.h5
# Saved weights to models2/weights_epoch_206950.h5
# Saved weights to models2/weights_epoch_207000.h5
# Saved weights to models2/weights_epoch_207050.h5
# Saved weights to models2/weights_epoch_207100.h5
# Saved weights to models2/weights_epoch_207150.h5
# Saved weights to models2/weights_epoch_207200.h5
# Saved weights to models2/weights_epoch_207250.h5
# Saved weights to models2/weights_epoch_207300.h5
# Saved weights to models2/weights_epoch_207350.h5
# Saved weights to models2/weights_epoch_207400.h5
# Saved weights to models2/weights_epoch_207450.h5
# Saved weights to models2/weights_epoch_207500.h5
# Saved weights to models2/weights_epoch_207550.h5
# Saved weights to models2/weights_epoch_207600.h5
# Saved weights to models2/weights_epoch_207650.h5
# Saved weights to models2/weights_epoch_207700.h5
# Saved weights to models2/weights_epoch_207750.h5
# Saved weights to models2/weights_epoch_207800.h5
# Saved weights to models2/weights_epoch_207850.h5
# Saved weights to models2/weights_epoch_207900.h5
# Saved weights to models2/weights_epoch_207950.h5
# Saved weights to models2/weights_epoch_208000.h5
# Saved weights to models2/weights_epoch_208050.h5
# Saved weights to models2/weights_epoch_208100.h5
# Saved weights to models2/weights_epoch_208150.h5
# Saved weights to models2/weights_epoch_208200.h5
# Saved weights to models2/weights_epoch_208250.h5
# Saved weights to models2/weights_epoch_208300.h5
# Saved weights to models2/weights_epoch_208350.h5
# Saved weights to models2/weights_epoch_208400.h5
# Saved weights to models2/weights_epoch_208450.h5
# Saved weights to models2/weights_epoch_208500.h5
# Saved weights to models2/weights_epoch_208550.h5
# Saved weights to models2/weights_epoch_208600.h5
# Saved weights to models2/weights_epoch_208650.h5
# Saved weights to models2/weights_epoch_208700.h5
# Saved weights to models2/weights_epoch_208750.h5
# Saved weights to models2/weights_epoch_208800.h5
# Saved weights to models2/weights_epoch_208850.h5
# Saved weights to models2/weights_epoch_208900.h5
# Saved weights to models2/weights_epoch_208950.h5
# Saved weights to models2/weights_epoch_209000.h5
# Saved weights to models2/weights_epoch_209050.h5
# Saved weights to models2/weights_epoch_209100.h5
# Saved weights to models2/weights_epoch_209150.h5
# Saved weights to models2/weights_epoch_209200.h5
# Saved weights to models2/weights_epoch_209250.h5
# Saved weights to models2/weights_epoch_209300.h5
# Saved weights to models2/weights_epoch_209350.h5

# %%
# %env PPID
